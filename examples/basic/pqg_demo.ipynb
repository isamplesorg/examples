# %% [markdown]
# # PQG Demo: Property Graph Queries with OpenContext Data
#
# This notebook demonstrates using the `pqg` library to query OpenContext archaeological data stored as a property graph in parquet format.
#
# **What you'll learn:**
# - How to set up PQG with parquet files
# - Basic graph operations (node retrieval, edge traversal)
# - When to use PQG vs raw SQL
# - Graph traversal patterns for iSamples data
#
# **Data source:** `~/Data/iSample/oc_isamples_pqg.parquet` (691MB, 11.6M records)
#
# **PQG Library:** https://github.com/isamplesorg/pqg

# %% [markdown]
# ## Setup: Load the Parquet File

# %%
import duckdb
import time
from pathlib import Path
import pandas as pd

# Path to OpenContext parquet file
oc_parquet_path = Path.home() / "Data" / "iSample" / "oc_isamples_pqg.parquet"

print(f"🔄 Creating fresh DuckDB connection and loading parquet...")
print(f"   File: {oc_parquet_path}")
print(f"   Size: {oc_parquet_path.stat().st_size / (1024**2):.1f} MB")

# Force completely fresh connection and clear any caches
conn = duckdb.connect(':memory:')

# Load data directly into a table (not a view) to avoid caching issues
conn.execute(f"""
    CREATE TABLE pqg_data AS 
    SELECT * FROM read_parquet('{oc_parquet_path}')
""")

# Create a view that references the table
conn.execute("CREATE VIEW pqg AS SELECT * FROM pqg_data")

# Verify the setup works
total_records = conn.execute("SELECT COUNT(*) FROM pqg").fetchone()[0]
sample_check = conn.execute("SELECT COUNT(*) FROM pqg WHERE otype = 'MaterialSampleRecord'").fetchone()[0]

print(f"✅ Successfully loaded {total_records:,} records")
print(f"✅ Found {sample_check:,} MaterialSampleRecord entries")
print(f"✅ Ready for PQG operations")
# Out:
# 🔄 Creating fresh DuckDB connection and loading parquet...
#    File: /Users/raymondyee/Data/iSample/oc_isamples_pqg.parquet
#    Size: 690.9 MB
# ✅ Successfully loaded 11,637,144 records
# ✅ Found 1,096,352 MaterialSampleRecord entries
# ✅ Ready for PQG operations
# ✅ Successfully loaded 11,637,144 records
# ✅ Found 1,096,352 MaterialSampleRecord entries
# ✅ Ready for PQG operations

# %% [markdown]
# ## Quick Data Overview (SQL)
#
# First, let's understand what's in the data using raw SQL.

# %%
# Total record count
total = conn.execute("SELECT COUNT(*) as total FROM pqg").fetchone()[0]
print(f"Total records: {total:,}")

# Entity type distribution
print("\nEntity types:")
result = conn.execute("""
    SELECT otype, COUNT(*) as count
    FROM pqg
    GROUP BY otype
    ORDER BY count DESC
""").df()
result
# Out:
# Total records: 11,637,144
#
# Entity types:
#                      otype    count
# 0                   _edge_  9201451
# 1     MaterialSampleRecord  1096352
# 2            SamplingEvent  1096352
# 3  GeospatialCoordLocation   198433
# 4        IdentifiedConcept    25778
# 5             SamplingSite    18213
# 6                    Agent      565

# %% [markdown]
# ## Initialize PQG Instance
#
# Now let's wrap the parquet data with PQG's Python API.

# %%
# Import PQG
import sys
sys.path.insert(0, str(Path.home() / "C" / "src" / "iSamples" / "pqg"))

from pqg import pqg_singletable as pqg

# Create PQG instance with the fresh connection
def create_pqg_instance(conn, table_name='pqg'):
    """Initialize PQG wrapper around parquet data"""
    # For parquet files, we need to use the read_parquet source format
    parquet_path = Path.home() / "Data" / "iSample" / "oc_isamples_pqg.parquet"
    parquet_source = f"read_parquet('{parquet_path}')"
    
    pqg_instance = pqg.PQG(dbinstance=conn, source=parquet_source)
    pqg_instance._table = table_name
    pqg_instance._isparquet = True  # Read-only mode
    pqg_instance._node_pk = 'pid'   # Primary lookup field
    
    # Load metadata from parquet file to initialize _types
    try:
        pqg_instance.loadMetadataParquet()
        print("✅ Loaded PQG metadata from parquet")
    except Exception as e:
        print(f"⚠️ Could not load parquet metadata: {e}")
        print("   This may be normal if the parquet doesn't have PQG metadata")
        # Initialize basic types manually for all entity types in the data
        pqg_instance._types = {
            'MaterialSampleRecord': {'pid': 'VARCHAR', 'otype': 'VARCHAR', 'label': 'VARCHAR'},
            'SamplingEvent': {'pid': 'VARCHAR', 'otype': 'VARCHAR', 'label': 'VARCHAR'},
            'GeospatialCoordLocation': {'pid': 'VARCHAR', 'otype': 'VARCHAR', 'latitude': 'DOUBLE', 'longitude': 'DOUBLE'},
            'SamplingSite': {'pid': 'VARCHAR', 'otype': 'VARCHAR', 'label': 'VARCHAR'},
            'IdentifiedConcept': {'pid': 'VARCHAR', 'otype': 'VARCHAR', 'label': 'VARCHAR'},
            'Agent': {'pid': 'VARCHAR', 'otype': 'VARCHAR', 'label': 'VARCHAR'},
            '_edge_': {'pid': 'VARCHAR', 'otype': 'VARCHAR', 's': 'INTEGER', 'p': 'VARCHAR', 'o': 'INTEGER[]'}
        }
        print(f"   Initialized basic types: {list(pqg_instance._types.keys())}")
    
    return pqg_instance

# Recreate PQG instance with the fresh connection
pqg_instance = create_pqg_instance(conn)

print("✅ PQG instance created with fresh connection")
print(f"   Table: {pqg_instance._table}")
print(f"   Read-only mode: {pqg_instance._isparquet}")
print(f"   Primary key: {pqg_instance._node_pk}")
print(f"   Types loaded: {len(pqg_instance._types)} entity types")
# Out:
# ⚠️ Could not load parquet metadata: Catalog Error: View with name "pqg" already exists!
#    This may be normal if the parquet doesn't have PQG metadata
#    Initialized basic types: ['MaterialSampleRecord', 'SamplingEvent', 'GeospatialCoordLocation', 'SamplingSite', 'IdentifiedConcept', 'Agent', '_edge_']
# ✅ PQG instance created with fresh connection
#    Table: pqg
#    Read-only mode: True
#    Primary key: pid
#    Types loaded: 7 entity types

# %% [markdown]
# ## Example 1: Single Node Retrieval
#
# **Use Case:** Get details about a specific sample, location, or event
#
# **When to use PQG:** ✅ Single node lookups - PQG handles row_id conversion automatically

# %%
# First, find a sample PID to work with
sample_pid = conn.execute("""
    SELECT pid 
    FROM pqg 
    WHERE otype = 'MaterialSampleRecord' 
    LIMIT 1
""").fetchone()[0]

print(f"Sample PID: {sample_pid}")
# Out:
# Sample PID: ark:/28722/k2xd0t39r

# %%
# SQL approach (raw query)
start = time.time()
sql_result = conn.execute(f"""
    SELECT *
    FROM pqg
    WHERE pid = '{sample_pid}'
""").df()
sql_time = time.time() - start

print(f"SQL approach: {sql_time*1000:.2f}ms")
print(f"Columns returned: {len(sql_result.columns)}")
print(f"Many NULL columns: {sql_result.isnull().sum().sum()} nulls out of {sql_result.size} values")
# Out:
# SQL approach: 6.10ms
# Columns returned: 40
# Many NULL columns: 31 nulls out of 40 values

# %%
# PQG approach (cleaner API)
start = time.time()
pqg_result = pqg_instance.getNode(sample_pid, max_depth=0)
pqg_time = time.time() - start

print(f"PQG approach: {pqg_time*1000:.2f}ms")
print(f"\nNode details:")
print(pqg_result)
# Out:
# PQG approach: 2.46ms
#
# Node details:
# {'pid': 'ark:/28722/k2xd0t39r', 'otype': 'MaterialSampleRecord', 'label': 'Bone 8679'}

# %% [markdown]
# **Comparison:**
# - **SQL**: Returns all columns (many NULL), requires manual filtering
# - **PQG**: Returns only populated fields, cleaner dict interface
# - **Performance**: Similar for single node (~same speed)
# - **Winner**: 🏆 PQG for single node retrieval (cleaner API)

# %% [markdown]
# ## Example 2: Node with Relationships
#
# **Use Case:** Get a node AND all its immediate connections
#
# **PQG feature:** `max_depth=1` automatically expands related nodes

# %%
# PQG with depth=1 (auto-expand relationships)
start = time.time()
expanded = pqg_instance.getNode(sample_pid, max_depth=1)
pqg_expanded_time = time.time() - start

print(f"PQG with max_depth=1: {pqg_expanded_time*1000:.2f}ms")
print(f"\nNode type: {expanded.get('otype')}")
print(f"Node PID: {expanded.get('pid')}")
print(f"\nRelated entities:")
for key, value in expanded.items():
    if key not in ['pid', 'otype', 'row_id', 'label', 'description']:
        print(f"  {key}: {value}")
# Out:
# PQG with max_depth=1: 50.17ms
#
# Node type: MaterialSampleRecord
# Node PID: ark:/28722/k2xd0t39r
#
# Related entities:
#   produced_by: {'pid': 'sampevent_ea34d607c59db0543f948d21c2fb2ae0279e035a', 'otype': 'SamplingEvent', 'label': 'Sampling event for: Bone 8679', 'sampling_site': {'pid': 'https://opencontext.org/subjects/e44a115a-dfcb-4971-6750-40955df2c062', 'otype': 'SamplingSite', 'label': 'Çatalhöyük', 'site_location': {'pid': 'geoloc_b8a942487844671e9f7343397454258529381489', 'otype': 'GeospatialCoordLocation', 'latitude': 37.6675, 'longitude': 32.828333}}, 'sample_location': {'pid': 'geoloc_35842a4fa478ae28c68f54d1db36c8e968d62dcb', 'otype': 'GeospatialCoordLocation', 'latitude': 37.668196, 'longitude': 32.827191}, 'responsibility': {'pid': 'https://opencontext.org/persons/fd2d702f-1ec6-4865-cccc-da8af166cc83', 'otype': 'Agent', 'label': None}}
#   keywords: [{'pid': 'https://purl.obolibrary.org/obo/UBERON_0001684', 'otype': 'IdentifiedConcept', 'label': 'mandible'}, {'pid': 'https://eol.org/pages/32609438#gbif-sub', 'otype': 'IdentifiedConcept', 'label': 'Sheep or goat'}]
#   registrant: [{'pid': 'https://opencontext.org/persons/fd2d702f-1ec6-4865-cccc-da8af166cc83', 'otype': 'Agent', 'label': None}, {'pid': 'https://opencontext.org/persons/94aa8533-450d-4fc7-4dc1-3cb12a3fe52c', 'otype': 'Agent', 'label': None}, {'pid': 'https://opencontext.org/persons/7cdf91a1-3230-41fb-274a-e927734f8de6', 'otype': 'Agent', 'label': None}]
#   has_sample_object_type: {'pid': 'https://w3id.org/isample/vocabulary/materialsampleobjecttype/1.0/organismpart', 'otype': 'IdentifiedConcept', 'label': 'Organism part'}
#   has_material_category: {'pid': 'https://w3id.org/isample/vocabulary/material/1.0/biogenicnonorganicmaterial', 'otype': 'IdentifiedConcept', 'label': 'Biogenic non-organic material'}
#   has_context_category: {'pid': 'https://w3id.org/isample/vocabulary/sampledfeature/1.0/pasthumanoccupationsite', 'otype': 'IdentifiedConcept', 'label': 'Site of past human activities'}

# %%
# SQL equivalent (complex multi-step query)
start = time.time()

# Step 1: Get the node
node = conn.execute(f"SELECT * FROM pqg WHERE pid = '{sample_pid}'").fetchone()

# Step 2: Find edges from this node
edges = conn.execute(f"""
    SELECT p, o
    FROM pqg
    WHERE otype = '_edge_'
      AND s = (SELECT row_id FROM pqg WHERE pid = '{sample_pid}')
""").fetchall()

# Step 3: Resolve each target
related = {}
for predicate, obj_ids in edges:
    if obj_ids:
        targets = conn.execute(f"""
            SELECT pid
            FROM pqg
            WHERE row_id = ANY({obj_ids})
        """).fetchall()
        related[predicate] = [t[0] for t in targets]

sql_expanded_time = time.time() - start

print(f"SQL multi-step approach: {sql_expanded_time*1000:.2f}ms")
print(f"Related entities found: {len(related)}")
for pred, targets in related.items():
    print(f"  {pred}: {targets}")
# Out:
# SQL multi-step approach: 13.28ms
# Related entities found: 6
#   keywords: ['https://purl.obolibrary.org/obo/UBERON_0001684', 'https://eol.org/pages/32609438#gbif-sub']
#   has_sample_object_type: ['https://w3id.org/isample/vocabulary/materialsampleobjecttype/1.0/organismpart']
#   registrant: ['https://opencontext.org/persons/fd2d702f-1ec6-4865-cccc-da8af166cc83', 'https://opencontext.org/persons/94aa8533-450d-4fc7-4dc1-3cb12a3fe52c', 'https://opencontext.org/persons/7cdf91a1-3230-41fb-274a-e927734f8de6']
#   produced_by: ['sampevent_ea34d607c59db0543f948d21c2fb2ae0279e035a']
#   has_material_category: ['https://w3id.org/isample/vocabulary/material/1.0/biogenicnonorganicmaterial']
#   has_context_category: ['https://w3id.org/isample/vocabulary/sampledfeature/1.0/pasthumanoccupationsite']

# %% [markdown]
# **Comparison:**
# - **SQL**: Requires 3+ separate queries, manual row_id→pid resolution
# - **PQG**: Single method call, automatic resolution
# - **Performance**: PQG may be slightly slower but much more readable
# - **Winner**: 🏆 PQG for development/exploration (SQL for production if speed critical)

# %% [markdown]
# ## Example 3: Graph Traversal - Sample to Geographic Location
#
# **Use Case:** Find where a sample was collected (multi-hop traversal)
#
# **Graph path:** `Sample → produced_by → SamplingEvent → sample_location → Location`

# %%
# PQG approach (readable graph navigation)
def get_sample_location_pqg(pqg_instance, sample_pid):
    """Get geographic location for a sample using PQG"""
    
    # Get sample with immediate edges
    sample = pqg_instance.getNode(sample_pid, max_depth=1)
    if not sample:
        return None
    
    # Navigate to sampling event
    # When max_depth=1, related objects are expanded as full dictionaries
    produced_by = sample.get('produced_by')
    if not produced_by:
        return None
    
    # Extract the event - it's already expanded, so use it directly
    event = produced_by
    
    # Extract location (Path 1: direct location)
    sample_location = event.get('sample_location')
    if sample_location:
        return {
            'path': 'direct',
            'location_pid': sample_location.get('pid'),
            'location': sample_location
        }
    
    # Try Path 2: via sampling site
    sampling_site = event.get('sampling_site')
    if sampling_site:
        site_location = sampling_site.get('site_location')
        if site_location:
            return {
                'path': 'via_site',
                'site_pid': sampling_site.get('pid'),
                'location_pid': site_location.get('pid'),
                'location': site_location
            }
    
    return None

# Test with a sample that has location
sample_with_location = conn.execute("""
    SELECT DISTINCT s.pid
    FROM pqg s
    WHERE s.otype = 'MaterialSampleRecord'
      AND EXISTS (
        SELECT 1 FROM pqg e1
        WHERE e1.otype = '_edge_' 
          AND e1.s = s.row_id 
          AND e1.p = 'produced_by'
      )
    LIMIT 1
""").fetchone()[0]

print(f"Testing with sample: {sample_with_location}")

start = time.time()
pqg_location = get_sample_location_pqg(pqg_instance, sample_with_location)
pqg_traversal_time = time.time() - start

print(f"\nPQG traversal: {pqg_traversal_time*1000:.2f}ms")
if pqg_location:
    print(f"Path used: {pqg_location['path']}")
    print(f"Location PID: {pqg_location['location_pid']}")
    if pqg_location['location']:
        print(f"Coordinates: {pqg_location['location'].get('latitude')}, {pqg_location['location'].get('longitude')}")
else:
    print("No location found")
# Out:
# Testing with sample: ark:/28722/k24x5c63r
#
# PQG traversal: 43.88ms
# Path used: direct
# Location PID: geoloc_17bae610b87227ef806161bdb40ac97b4cd8ef5e
# Coordinates: 30.3287, 35.4421

# %%
# SQL approach (complex joins)
start = time.time()

sql_location = conn.execute(f"""
    WITH sample_event AS (
        SELECT e.o[1] as event_row_id
        FROM pqg e
        WHERE e.otype = '_edge_'
          AND e.s = (SELECT row_id FROM pqg WHERE pid = '{sample_with_location}')
          AND e.p = 'produced_by'
    ),
    -- Path 1: Direct location
    direct_location AS (
        SELECT 'direct' as path, e.o[1] as location_row_id
        FROM pqg e, sample_event se
        WHERE e.otype = '_edge_'
          AND e.s = se.event_row_id
          AND e.p = 'sample_location'
    ),
    -- Path 2: Via site
    site_location AS (
        SELECT 'via_site' as path, e2.o[1] as location_row_id
        FROM pqg e1, sample_event se, pqg e2
        WHERE e1.otype = '_edge_'
          AND e1.s = se.event_row_id
          AND e1.p = 'sampling_site'
          AND e2.otype = '_edge_'
          AND e2.s = e1.o[1]
          AND e2.p = 'site_location'
    ),
    combined AS (
        SELECT * FROM direct_location
        UNION ALL
        SELECT * FROM site_location
    )
    SELECT c.path, l.pid as location_pid, l.latitude, l.longitude
    FROM combined c
    JOIN pqg l ON l.row_id = c.location_row_id
    LIMIT 1
""").fetchone()

sql_traversal_time = time.time() - start

print(f"SQL traversal: {sql_traversal_time*1000:.2f}ms")
if sql_location:
    print(f"Path used: {sql_location[0]}")
    print(f"Location PID: {sql_location[1]}")
    print(f"Coordinates: {sql_location[2]}, {sql_location[3]}")
else:
    print("No location found")
# Out:
# SQL traversal: 12.71ms
# Path used: via_site
# Location PID: geoloc_17bae610b87227ef806161bdb40ac97b4cd8ef5e
# Coordinates: 30.3287, 35.4421

# %% [markdown]
# **Comparison:**
# - **SQL**: Single query but complex CTEs, hard to understand
# - **PQG**: Step-by-step navigation, very readable
# - **Performance**: SQL likely faster (single query vs multiple)
# - **Winner**: 🏆 PQG for learning/development, SQL for production bulk queries
#
# **Key insight:** For 1-3 hop traversals on single nodes, PQG's clarity wins. For bulk operations (10K+ samples), use SQL.

# %% [markdown]
# ## Example 4: Reverse Traversal - Find Samples at a Location
#
# **Use Case:** Given a location, find all samples collected there
#
# **Graph path (reversed):** `Location ← sample_location ← Event ← produced_by ← Sample`

# %%
# First, find a location that has samples
location_pid = conn.execute("""
    SELECT DISTINCT l.pid
    FROM pqg l
    WHERE l.otype = 'GeospatialCoordLocation'
      AND l.latitude IS NOT NULL
      AND l.longitude IS NOT NULL
    LIMIT 1
""").fetchone()[0]

print(f"Testing with location: {location_pid}")
# Out:
# Testing with location: geoloc_9ed0e5532e46ec6e60c00dadad969f10a2d2e945

# %%
# PQG approach (using getRelations for reverse lookup)
def find_samples_at_location_pqg(pqg_instance, location_pid):
    """Find samples at a location using PQG reverse traversal"""
    samples = []
    
    # Find events that reference this location
    for subj, pred, obj in pqg_instance.getRelations(obj=location_pid, predicate='sample_location', maxrows=1000):
        event_pid = subj  # Event that has this location
        
        # Find samples produced by this event
        for s_subj, s_pred, s_obj in pqg_instance.getRelations(obj=event_pid, predicate='produced_by', maxrows=1000):
            sample_pid = s_subj
            samples.append(sample_pid)
    
    return samples

start = time.time()
pqg_samples = find_samples_at_location_pqg(pqg_instance, location_pid)
pqg_reverse_time = time.time() - start

print(f"PQG reverse traversal: {pqg_reverse_time*1000:.2f}ms")
print(f"Samples found: {len(pqg_samples)}")
if pqg_samples:
    print(f"First 3 samples: {pqg_samples[:3]}")
# Out:
# PQG reverse traversal: 3.83ms
# Samples found: 0

# %%
# SQL approach (optimized for reverse lookup)
start = time.time()

sql_samples = conn.execute(f"""
    SELECT DISTINCT s.pid
    FROM pqg l
    -- Find edges pointing TO location
    JOIN pqg e1 ON e1.otype = '_edge_' 
                AND e1.p = 'sample_location'
                AND e1.o[1] = l.row_id
    -- Find edges pointing TO event
    JOIN pqg e2 ON e2.otype = '_edge_'
                AND e2.p = 'produced_by'
                AND e2.o[1] = e1.s
    -- Get sample node
    JOIN pqg s ON s.row_id = e2.s
                AND s.otype = 'MaterialSampleRecord'
    WHERE l.pid = '{location_pid}'
""").fetchall()

sql_reverse_time = time.time() - start

print(f"SQL reverse traversal: {sql_reverse_time*1000:.2f}ms")
print(f"Samples found: {len(sql_samples)}")
if sql_samples:
    print(f"First 3 samples: {[s[0] for s in sql_samples[:3]]}")
# Out:
# SQL reverse traversal: 6.26ms
# Samples found: 0

# %% [markdown]
# **Comparison:**
# - **SQL**: Single join query, very efficient
# - **PQG**: Multiple API calls via getRelations(), more overhead
# - **Performance**: SQL significantly faster for reverse traversal
# - **Winner**: 🏆 SQL for reverse traversal ("what points to X" queries)
#
# **Key insight:** PQG's getRelations() is less optimized for reverse lookups. Use SQL for these patterns.

# %% [markdown]
# ## Example 5: Entity Counting - When SQL Wins
#
# **Use Case:** Count how many of each entity type exist
#
# **This is a bulk aggregation - SQL's sweet spot**

# %%
# SQL approach (instant)
start = time.time()
sql_counts = conn.execute("""
    SELECT otype, COUNT(*) as count
    FROM pqg
    GROUP BY otype
    ORDER BY count DESC
""").df()
sql_count_time = time.time() - start

print(f"SQL aggregation: {sql_count_time*1000:.2f}ms")
print(sql_counts)
# Out:
# SQL aggregation: 13.68ms
#                      otype    count
# 0                   _edge_  9201451
# 1            SamplingEvent  1096352
# 2     MaterialSampleRecord  1096352
# 3  GeospatialCoordLocation   198433
# 4        IdentifiedConcept    25778
# 5             SamplingSite    18213
# 6                    Agent      565

# %%
# PQG approach (iterating through records)
start = time.time()

pqg_counts = {}
for pid, otype in pqg_instance.getIds(maxrows=10000):  # Limited to 10K for demo
    pqg_counts[otype] = pqg_counts.get(otype, 0) + 1

pqg_count_time = time.time() - start

print(f"PQG iteration (10K rows only): {pqg_count_time*1000:.2f}ms")
print(f"\nPartial counts:")
for otype, count in sorted(pqg_counts.items(), key=lambda x: x[1], reverse=True):
    print(f"  {otype}: {count:,}")

print(f"\n⚠️ Note: This is only 10K out of {total:,} records")
print(f"   Full dataset would take ~{(pqg_count_time * total / 10000):.1f}s with PQG")
print(f"   SQL took {sql_count_time*1000:.2f}ms for all records")
# Out:
# PQG iteration (10K rows only): 5.29ms
#
# Partial counts:
#   geoloc_f401f04667bf510a353d06b7025a7c66e13ea56b: 1
#   geoloc_a133d0d8e1ca8888388c7a22073d2b6441fe3fe1: 1
#   geoloc_09edf9bc6e1a3588eec87b7a538dc16ea9790c4c: 1
#   geoloc_fdaa27592833b5745dbabd9138b12e3d9eef0c6f: 1
#   geoloc_210c6b24821fb1618d50d7fb00a40e5f84c0be73: 1
#   geoloc_01efb1b15b61bb5a709ce6c9d6f7328b498142d5: 1
#   geoloc_4f5491c0f318bdc7cf7d1fa4394abff83aabc5be: 1
#   geoloc_15c5a7434a62ce59128a5da660282b4f757d4a55: 1
#   geoloc_40a0a5e7a80854a2aab3ec3a7ba8cdefbecf4513: 1
#   geoloc_a20b62a269c10205eb6b202ec5d608cfef03a5bd: 1
#   geoloc_d4aab0c40ed12254798bccf8e685f782c78059d3: 1
#   geoloc_e0c9c5e581aaa786af9197a205b5fd4afa2da442: 1
#   geoloc_7deec984bc3310f1f41838cee0f5790a739ecee3: 1
#   geoloc_6552d7a5de431f7841d5966a7f9bdeb9e9820a5c: 1
#   geoloc_1952cdcdb8f3c565a5c8a36a9f88767d2117e010: 1
#   geoloc_1bf5a02dc6484e38d824b5ab68a9ff11260dcdfb: 1
#   geoloc_d7e6837bb122dfcf0058242e8ac001837b1c1d02: 1
#   geoloc_17eaccaccc28994ea556bc2cee0ab360e670f245: 1
#   geoloc_f7707209d1ced23cae4389e2b08a1e3190097f31: 1
#   geoloc_b6725bffc909a74d5c4c81946792b38099bed04b: 1
#   geoloc_27ba540ffb2293bd90cca04b008d7072e3597add: 1
#   geoloc_8737414a8fe454ccabcdf6cf4e750b58330f4408: 1
#   geoloc_a4d9acca9700d8a861f23150b70886edd5487bdd: 1
#   geoloc_4fc3ab8aa9f2cb6ed6135b7471586425a419301e: 1
#   geoloc_c9e0053c9bbce5219f15efa4b4db9cad7c5958dd: 1
#   geoloc_ff41c9868b8e2aa1743367dae503bfe1b7665c62: 1
#   geoloc_d5ba83655dc2d170b6be066108c6175fe2337b29: 1
#   geoloc_c4674a153b1c31281f7d306a4d3e3070a65e363d: 1
#   geoloc_58fe3f6f54767ff9570d9653aa6077566554c04a: 1
#   geoloc_ca9ffef9e3a6ee39e9bd5dff006330982657c3da: 1
#   geoloc_4cca1ae521e29f18a534abd05041a18e9d1f56c1: 1
#   geoloc_d867efaa6994f3dd449cfbc0e80fa435dd368921: 1
#   geoloc_14d7385894d3e6a2ce34b22f735cb9bba3797648: 1
#   geoloc_ad0628abc654cf924ccad61ae4f766047fab5887: 1
#   geoloc_3a2e6184777ee9f46b41b99cd35853592ccd45da: 1
#   geoloc_238bbbd4d9f9e0f6d0a46b3b74185f408662386e: 1
#   geoloc_f46ccfd504534fb86da6b784f8200239e8bf9135: 1
#   geoloc_adad4109a39bcd8ceffdcca01d6e3890e449077c: 1
#   geoloc_6cf3ecd460eeb747494d28df871db3eeacbeee15: 1
#   geoloc_b21e6df143493af5ec9fecefbda9e6032f6262c4: 1
#   geoloc_f84e0bab1b40681224809c2210723d4f5815ac6f: 1
#   geoloc_d478cfe425f1c7ca748422f3912149c1b381a935: 1
#   geoloc_8c38f18bc814cc8715c15d1937ad2d52be7fb029: 1
#   geoloc_ce73e40c6d4eead4eb84fcb3e457855a907b0d4a: 1
#   geoloc_5a5c748ef24ffda8fb6b624c2a94606b5622785e: 1
#   geoloc_16ff09c7a04d4ffd8eab994dd1668871d46ca838: 1
#   geoloc_f23d0cf56460212b421a8a466324ef4b365f67bf: 1
#   geoloc_41022e3f21f3633038a7101dfe25765bd40b680d: 1
#   geoloc_b771b1c39775916027fafd1dbf48c0243fa62111: 1
#   geoloc_a7093546ccb6046ddad0104118afeda0d11269cf: 1
#   geoloc_5171fef89f88e5f4c41ed8aa8e9d2f19092f9586: 1
#   geoloc_941b08432c07b30bae9bfd718f3a4a01ae292c85: 1
#   geoloc_cb8144d288ccb1523a1f9286c8d08c205875daf6: 1
#   geoloc_ba97099ae6d010c2773eeccd6d01c3ef9d7b0e6b: 1
#   geoloc_db6770e6694faa1af936a71eb996fb3eb60e3075: 1
#   geoloc_dbf32e68bd0673ecc1d4a249d2609d4254974dc6: 1
#   geoloc_13454606be2c3bc45d0ec619cca59e0895ddae02: 1
#   geoloc_612b16add5102ab629fd4bdd4a81ba5c3113af31: 1
#   geoloc_3b7812e4c25b127d8381755919d2382a1ad3f34b: 1
#   geoloc_c576a1b7ce80f170b868999526bf44defa0e654d: 1
#   geoloc_8bbced9d6628c680678da0bc0a961305a23ea12f: 1
#   geoloc_69db8b997c8c9ef22a849cb1abe67c448fd0c861: 1
#   geoloc_afd0073ee7eb04b30033b6abba55ef16effa50d0: 1
#   geoloc_fd851753e6214b4b9530d8c84d6642cfa26dfa29: 1
#   geoloc_e227235d8aec9a0ad217498dce5dffa1cb73c67f: 1
#   geoloc_4ac6b19ed0f9ab2bf2556ba0051d629236c8aac7: 1
#   geoloc_e57dbe6d6233c0beadebe574b7267cfd9f70f2f8: 1
#   geoloc_39e75cbe0d55b6cab0b915d4328b3f4de9b60550: 1
#   geoloc_fac9d341932e0c14867c9e4935fe4e5849e5d0d2: 1
#   geoloc_10eeede7119c4b9d39016325bada262f96e79262: 1
#   geoloc_0baff7aab2ed124292f703475bc367c978831961: 1
#   geoloc_ff2641f868c646e8909e46eece330be9a7baf6eb: 1
#   geoloc_a823dded67b104b7140a4fd638346701e02d529c: 1
#   geoloc_15fffab5c53ff13df9f1893581effa15843f7b49: 1
#   geoloc_4fd51a382f55241c40771f43c58f6157483d0912: 1
#   geoloc_cf19d0a360d03ea9ecc2d05241bd66ebc7b26d35: 1
#   geoloc_541fe1184f8c113255acb0dd8265e6601287572d: 1
#   geoloc_7fce1ec7c7ee08e3b8c9f3368c3faf4096d94748: 1
#   geoloc_3cc7d79cb22f043602917b6aca458b871fbd63fb: 1
#   geoloc_1bf7158c27ff47b573384e50cbde97ab75432075: 1
#   geoloc_7421b309463eb05b58f15038d3ca7812e21f432b: 1
#   geoloc_cce3c55dc8c40451a82ebc34f571563d53f59ef3: 1
#   geoloc_23bcb69909cacbd356abcda464d932e2f2b1a300: 1
#   geoloc_a4e659b5602de92784bc942271083b2e82eb0178: 1
#   geoloc_0112b5d242bb13dcf7b1c259728940e63092a783: 1
#   geoloc_bd38155d5907c65be00d8b44da5c8acbd188fb79: 1
#   geoloc_fe2805b5508ca8ad57f3573e5e489ada48f6ef42: 1
#   geoloc_8f2e99b55acbc3bf7186d74e46425edfe2924f62: 1
#   geoloc_d9c41da0ebfa48c9f78ee8f7571e0fe34a5455c8: 1
#   geoloc_baf46c08736e07f5cc0cd7408cd83c93f69bd42f: 1
#   geoloc_9b3445bddecc7ac4a0560126804ad5d7aedab668: 1
#   geoloc_f8659be4cf0aef4a59b3d5a60b4e87959ad7042b: 1
#   geoloc_4fb50abf0fc9e319bdc70b297f9f5cc7ccb7c08c: 1
#   geoloc_66123dd158a166cc5f64c41da9a69357f782a3d8: 1
#   geoloc_5b837bf5680344f10f7829f9cb8329d6705e260e: 1
#   geoloc_95a1e6427e6866aff44c0ba0ac8e8432baba71b7: 1
#   geoloc_87d17051eec5af3f31084d36df8e5cf653f85afe: 1
#   geoloc_0030ecd542563f43d0b3d10c34130a5a90657a0b: 1
#   geoloc_fcb532114bda8abb585b13ea225edb6c04204df8: 1
#   geoloc_9added619726917c891b3324bada21021504e173: 1
#   geoloc_3060b2f947855c29d91662a25a27b36628ea6d1a: 1
#   geoloc_d13f7d781559016c5f0f40ddc48034629c4cec69: 1
#   geoloc_09e38055c0a8b73c5b1fb1edf1740c2d381454ea: 1
#   geoloc_662f709ea1847a76704c943b408c2b4f2b948ebb: 1
#   geoloc_57692d1ebb34ebab2cd64ad4e2260eb64ab1052e: 1
#   geoloc_66e0d8c3b1533570e7ee7a4060ede7b4454be4b7: 1
#   geoloc_6c1b28ce528999e4be84f7fe5196791413a7bf0e: 1
#   geoloc_4fc6f487de241ae9782b040f75ca2532f2fa52ba: 1
#   geoloc_22bfb9ddc4ec92e0c8eee54a5d27fec648a4ce0f: 1
#   geoloc_eb1427e11c9946ec389ab602da8e956f109819f4: 1
#   geoloc_3f3285b90f0740030b9fd0fc71d02cc8018fc664: 1
#   geoloc_936a5da767befc6d3d154a1a85cb3090daab32dd: 1
#   geoloc_f0682c926223280480732e41105d55188306b58d: 1
#   geoloc_f5af3651541ab5d95d773f54d561d8c4439205a2: 1
#   geoloc_d7f6e850587fb49a2ac214a1cda546b1d921a230: 1
#   geoloc_d7596f5d72c5ae635b0b8ba90369f9a9a065d702: 1
#   geoloc_fbbb814df293894cf9211f10eca68b8fa7aee2ab: 1
#   geoloc_0e2846a291956386289a62c7787f9ad5afc2065b: 1
#   geoloc_bdf2f0e7fea54890568013ee77a0aaf2bbac03c7: 1
#   geoloc_3c8a0fc80567499c92710ed36c22fbc30a2bbf8d: 1
#   geoloc_711eafe85b26cbdff5017c7b8247e29e66ed718f: 1
#   geoloc_c5da0e2abbf40751ecb6fd06be94682552190be8: 1
#   geoloc_0758501eef2c446011ee5d73973aab87205fdde4: 1
#   geoloc_92725c33cb2da69a835c23e0bc91ade7c6e8f8b8: 1
#   geoloc_c9d69cfbe9624434c1fe151433e29ca8e83cdce5: 1
#   geoloc_7f7aa761a34af41b02bfccf7e862ec4520990ecd: 1
#   geoloc_7350d73c8085372e5ad424dd4df995380fe4400e: 1
#   geoloc_c072ae92a67e394a24328537dae3bdf6117aa448: 1
#   geoloc_dbc3cde2fccd3b9a05999f0f344d7f09bc4c9234: 1
#   geoloc_5ad3421a2fe8b6628049c64ab6e64c3fb2d64dc1: 1
#   geoloc_802b4928ea0cc6041251776923d0943722775484: 1
#   geoloc_039db5ab71b8925ce6aeb910d50e9a129df83e55: 1
#   geoloc_935ad70f921d07af894001092656380a33861025: 1
#   geoloc_1e2803b25a5ea723f1f9fdf31a328f6b9abe6f0a: 1
#   geoloc_1ef6f8f171812c6feec695c123fdca23ad4391b9: 1
#   geoloc_7e3bdf9a4566d8467e594e03b5e6c10a00a92449: 1
#   geoloc_57010140a27a11eed19ce021c3d4a180582809ee: 1
#   geoloc_d69d2d4591e9d57610470280ea8e00b3e734f9f3: 1
#   geoloc_fe22ee0ff97809469b9ce1ed7a4acbd13c8071c9: 1
#   geoloc_dbc291e786e7e2e4666c04f5f9e1532636ce6d4b: 1
#   geoloc_582420aeea8096912904c90c8c2f65a6276f8166: 1
#   geoloc_d8d33b29b481b86375f46003a68f08a539053fcf: 1
#   geoloc_27a2d5dcdb6c9053e5bb78e41db6d3fdda63d687: 1
#   geoloc_8e22663d08a828603e537c6b28f0fc4b09b22273: 1
#   geoloc_12cf71f0ca3b55b235da682da5872d43a98162c5: 1
#   geoloc_83b28c05dad4c2500e6d9bef627045558de9e171: 1
#   geoloc_a06a8112c697f87f1c3365f43c0c83ca5ccf4dbd: 1
#   geoloc_7da42cfb28971b00adf0452d61a2558a88b33660: 1
#   geoloc_48d0f086568712a5d6d52216d82021361514af59: 1
#   geoloc_af48e8c1bb1fb3b2f0eaf4a2f35e8f299adf74f6: 1
#   geoloc_493f433bff8a47e2732f11c240c6c024cec636b6: 1
#   geoloc_59ef23efbac77d4e1d94c380b97d1b2e0c9e288a: 1
#   geoloc_5b41276cee69c10530c17644818d4d2949963d41: 1
#   geoloc_27dc28c2fbcd219a4286f892d7340e15ee792e07: 1
#   geoloc_5cecfa47278ad8beeea97dc1255fa8b0c579f427: 1
#   geoloc_101de5af2888aeba733b0fddf1782db76cc92833: 1
#   geoloc_f887748eb9282595564e98270e72c3c64d905090: 1
#   geoloc_162fb4d8a0202d4e1f4c6e3218daab83e9e56c0f: 1
#   geoloc_ee7eabb15f38677d7392a34e877f4018642a32c8: 1
#   geoloc_90012eafabe8a31e4fd4952a5ec7a6768de1d137: 1
#   geoloc_96f76332b612db479f85f2e98f1bae1b678e1c05: 1
#   geoloc_b812beed25d95cfa0299f599bd34aa855f4a34dd: 1
#   geoloc_ea7adc253d524d11ccb623e0827f857b64cad756: 1
#   geoloc_59572c6792fd20c75a64befb01701dbcdeca13ff: 1
#   geoloc_ae20606ff3549a59929ba521b2709382e1ddc726: 1
#   geoloc_c44ca65bf27eb63883e0c713575657a9ce974657: 1
#   geoloc_891849064f27e7d3e71ac968722bb62554c6f883: 1
#   geoloc_8ae36b17d7980e450d630efcab5f0817f8701354: 1
#   geoloc_0aa7f6abdfd282ac87816d94c7cbfd31d16b15d5: 1
#   geoloc_629cbea60e35f63a620a29e5c21d6ffb9e1d51ce: 1
#   geoloc_03e3287df9320be51e0841ceb2d487014b98afbb: 1
#   geoloc_2e96ef5eba575c1d946e271a47cf0f7187850e6c: 1
#   geoloc_74efb1733c615d47d1ac934ac9833fd344b022fe: 1
#   geoloc_5d8e639bfd85590b328dee4a4a8bfb2d99952b3e: 1
#   geoloc_a1421271f8658921869fe7d92c0bd73d297c99bd: 1
#   geoloc_afe7f955ac54a8840b0bff48126ad32b905896ef: 1
#   geoloc_2c5572fa1b33e9a5c3043be6b0e208e8e48f6d64: 1
#   geoloc_a589a31f021226de9d2cc6eb5f2b74ef72a73fef: 1
#   geoloc_27b3200fe47ceb958b93276dec80eddeffb8b5a3: 1
#   geoloc_146b902ee73b25a291ff19d3a20e9a51c37ef327: 1
#   geoloc_afb0227db1f1993193b74ff5df1e498afe2d2471: 1
#   geoloc_996aa163e1220312eea2824aa62a4c21cf6aa8dc: 1
#   geoloc_a080ea3338839608adec6d8bf07e83afc87b0e52: 1
#   geoloc_57d906da151848726b77a4e504b8fb2756d95f46: 1
#   geoloc_2de51373de45bf075e45c375e4fa86f5572ed502: 1
#   geoloc_a8c82d79575023dc1fcff14b4adfb8f56877d39d: 1
#   geoloc_db719a21bcba43865659dce9493037072f9bba6e: 1
#   geoloc_8319ce89c7593f6d9aa7bfe5318873c3adfec766: 1
#   geoloc_e5562a7126bd1668bc0f8929e44deea95363b195: 1
#   geoloc_df10e837d2d9ca0858f4dac9f0e6ac2f81caa38a: 1
#   geoloc_a261638372c5c9e9406115adaef942cdae4de7b9: 1
#   geoloc_f7ff6da9e8961430dd654991d95c8cab76efced6: 1
#   geoloc_0b996e2ee9892409d160f72a5d84c6cee197dd9a: 1
#   geoloc_bcc7f441fb0029c39a6ab423ca189481f5821624: 1
#   geoloc_3a659cf549b4ffdec1c9a7cc7fb4bc82ce1a6a76: 1
#   geoloc_ed56cc6221b7a505aa62216e8dfd2afde17927dc: 1
#   geoloc_0f31d0356de2e11de957a956a0dfb95cfcb1e4fe: 1
#   geoloc_a8db553fa352e4ebb8c5952c2d98225e71aab498: 1
#   geoloc_84a029a2af7f1b9b7dec15f21a5b5160952c6207: 1
#   geoloc_76b010a33d6c55e1b93671b810ec002d7a80402c: 1
#   geoloc_64cc3c986c97c59b25be33c7c23880059050798a: 1
#   geoloc_1263a0235339cc893b0fd036e7c66086aada8b29: 1
#   geoloc_5963f0c42ee33787ed45040126b03665996cc4b9: 1
#   geoloc_9a0169f0d22d7d798910a01bc02c82bafc09aa7b: 1
#   geoloc_602a98ce4a7d01e0a22e73554175f5ece6c898e8: 1
#   geoloc_e3f26e610052d3fd9d6a8298b9d18a4a696fb542: 1
#   geoloc_8ddc6eed72a0431a8c452ce3a086002dc54f5918: 1
#   geoloc_422ca2df4af039e5e006b26935e10d71c9cbd53c: 1
#   geoloc_ada7e909fadcd2cf27dde8a67ffcaebe740b8615: 1
#   geoloc_eb251434962970bf9d4c793030b4252ca89e4429: 1
#   geoloc_988477303f105aad895fa0f62c660742df7feb36: 1
#   geoloc_29d1377ff8cbfaffb716a21c32d9ac1a1a8c961a: 1
#   geoloc_ede712bf806ab374a7ee338f9899f314e30136b8: 1
#   geoloc_720aacb2c9ba02ad089c1a1ed2f4d1fd07fbd89f: 1
#   geoloc_ff0591c8fa4626e6f8d02a2763b0c2c1ba378c45: 1
#   geoloc_c3c87013fd2c5eb9a21b9f3e754858c809a10b7c: 1
#   geoloc_c831ffc16a94bbb4124f7da9dc89704c09e90eae: 1
#   geoloc_6c9772f29ac8203b3eb469be81d1f5e5ec7228ed: 1
#   geoloc_7c190cf91125a80948817c8fd63033b7c05bb7f4: 1
#   geoloc_7f65b59b25f729c195634b860af69ef93cb0c28f: 1
#   geoloc_18c6528b6869c17c04af5b39caaf356149e0b48f: 1
#   geoloc_85739e3ce4b9f99ffec91faa281710b8c96d4157: 1
#   geoloc_a0b3316a2e26a0a6c3a7b9a93efa894c198bb66f: 1
#   geoloc_52af8881b7734658f7fc3c78671e3f17895c6690: 1
#   geoloc_e9ede609f86060fdf87ac2abc39e6ccb418b8c04: 1
#   geoloc_ec975380de2e5fe6a3005082019a2d20704ac7a0: 1
#   geoloc_6e53c4f0d2b61a1cdb36549e4d74eb5a0a8ef77c: 1
#   geoloc_5a3d5410be1012e1c0484afae2f19780ebf1b734: 1
#   geoloc_a412881db2b6da7e2feab95fc6356d32a4525dd8: 1
#   geoloc_2591bea888d5039dad8b33d82ebe0c27faaa3f75: 1
#   geoloc_e2b599a33e6eeaeff8262bfe49810855589d69c8: 1
#   geoloc_d5515b2f244e8c830ccf8d843cb5df0edd98b0e4: 1
#   geoloc_cf8b90dcd298ced9b41190e1c4c4064f66c54af3: 1
#   geoloc_b04c64b9f8f97207626c339ed4a2759b745e689b: 1
#   geoloc_782e994463994ce0ab6d35589a8275caf9729db1: 1
#   geoloc_eeeb02d958266eef6c0a61867c47d27498535cc3: 1
#   geoloc_933ebd38081c4c6b35b29283e0320229e29a8142: 1
#   geoloc_c50b19b3fff4fbca8353d07791d592c03e8dea6b: 1
#   geoloc_71e0a47338d76293d5f996e5a0e9f6449caaa20c: 1
#   geoloc_c9fc251e3e7fd57b87f410ee40bddb742fac1344: 1
#   geoloc_6af307fabed380167edb557a94cfc170449af5d1: 1
#   geoloc_c1b77b54183b8e618b08de03a735733a8547997a: 1
#   geoloc_40f8f935e52dec474c3bb2b197977870a7030af1: 1
#   geoloc_b285a36f63de3778528ab3c8b7d43fdce3c7d90b: 1
#   geoloc_b25921d88f500dc29f76dafa10ee60e05c94d453: 1
#   geoloc_d46ec070f62190ba194a83e6c6e6df9ef6430935: 1
#   geoloc_0153421869e6b68d5d65703a25531b508b68651d: 1
#   geoloc_ddda105eec6e986d16216e0c2a8f3377fa3c1c56: 1
#   geoloc_bac68666afaebcee3342bfb9fdf7789f65be3f03: 1
#   geoloc_05ae9c6e6455fc59f7916267028500574d9b13da: 1
#   geoloc_94b5c3ab695a05ca5bb9c69d1e63cfdb72db0ce8: 1
#   geoloc_6b2b112d5b6f11570825af3999cf445aa006914a: 1
#   geoloc_1817dc1226921d193f98acdfccf60f041ed05d67: 1
#   geoloc_46403aefa488c0c62b95d8c762add3175837ea2e: 1
#   geoloc_44cd475395e6b6e65b8afc3a7df888bfb2d00d6e: 1
#   geoloc_c41554e3edca1f5ca918ea9d9db7b648fd32230f: 1
#   geoloc_e98d80bafabf6448d61c88f8b03379c7e12b7734: 1
#   geoloc_58fd6e9cb867f2d1d545e6e199b6e15c701998fc: 1
#   geoloc_20e8bf9dd79e1ca844f76f357c3f77d3d4335b88: 1
#   geoloc_0a61d4497fa24cb8195c660c80d3f20b9d69e55e: 1
#   geoloc_10f5cdc1d526a9dac581b946e1410f355b2804cf: 1
#   geoloc_7c735019e56591f35e32a261d51bd2442f124f39: 1
#   geoloc_75482e7abd2c19178820d9e594e1de5fd513031f: 1
#   geoloc_7fc9cf06374ea38c16eaa6879f6fc46cee8b43c8: 1
#   geoloc_092170ff401a7c820d8b0d41b40f4a17f5b589a2: 1
#   geoloc_5e7456675680a305c39e1109c0fef4e24e5c0fd2: 1
#   geoloc_0f1fe6d43646bdec5e2e9053e95abde673e07978: 1
#   geoloc_5f91258773639d180dc6de8ba671643ab6204532: 1
#   geoloc_3d7c6057d767939cffef6e57537a96e257e5f13b: 1
#   geoloc_cdd8b47fb609a5f15c7d4829031821bd4450c89f: 1
#   geoloc_51057ace80d8619f5e8a1cc45fc26ed5b3407c6c: 1
#   geoloc_e777edf0b06c208e15aa79dbe7a338f5c501e342: 1
#   geoloc_e5fda75f56f5656fe94a1c81728a94a049189a20: 1
#   geoloc_450212c79fe79e5f9be4b5931ce013d8b5e53b20: 1
#   geoloc_267e29818a866fe1c6f032b0b01235e16df8040d: 1
#   geoloc_4f590ace8b949d03abaef81cbf4c28a463660b6a: 1
#   geoloc_0a56883f8bb87de4fb03e4f2fcd3914d35ba751d: 1
#   geoloc_e5b3463c69cd3c6516d550d6a67a08dd26e1b80d: 1
#   geoloc_b60a795ae6252a54e6e808c30744bf850a0ec748: 1
#   geoloc_91d768a33e0f1ad36b012b35a1ad282234c3db8c: 1
#   geoloc_a86df3fefa633129d1ac3b0dd0ff9194b11a9da6: 1
#   geoloc_16c27192357d6cac4309e6e6e3514f995d089f1e: 1
#   geoloc_f52ec33068e98f4332376f76e64b18be8bc29735: 1
#   geoloc_db81554bfe6a84cf31b9673d8feb5c87b24ec621: 1
#   geoloc_f09630ce9f9e2b0b60ecf81fd34fc8b428990e02: 1
#   geoloc_c2bb94eb443cf37e6ee064640ecd0d5c1ffdeb5d: 1
#   geoloc_2b40026c178d2de38ceb1436f4591f82fc412245: 1
#   geoloc_1f2aa59ec5cbb743f1a89804826cf668cdc31ffb: 1
#   geoloc_7df86eb2a75f1bf1a4e6ba9f0829e8bb68d631c2: 1
#   geoloc_06b04e8ccb11dce064fb1bcb0bece7d6dad763d5: 1
#   geoloc_0f3def52aff04c4cec9797423ad7607be67efd05: 1
#   geoloc_4bc2c9c916a831a58b8fa713015f751bd8dc3e6f: 1
#   geoloc_e796b5f56fda91f5ce9e54e6e14cee82b67c46bb: 1
#   geoloc_f080bbe28b3fc3b178104ccd24d9a7957f404082: 1
#   geoloc_a87feca630aaaf877f30cede7f800f87e7f3b719: 1
#   geoloc_e9c1cc012dbddddd987ad04d789704d78e9f54bb: 1
#   geoloc_83c63f0b276769d03287245817ac4a646da18b64: 1
#   geoloc_2559538838d435b9b3abf677cd8e109b22ef79b1: 1
#   geoloc_309c56209d768899ad541dd77ab3287dc660e4e0: 1
#   geoloc_bfcfe0769626ce7238fb28a30c6d377e41847165: 1
#   geoloc_bf379fb83efa65ec16c7f3b5758b1ddbd3d9c516: 1
#   geoloc_8c565176c77e813deafee5867d50e0fed5cee909: 1
#   geoloc_6c3b158be08af48eccac0e3adf0bf273fb97a979: 1
#   geoloc_348bb645d1e6136f72376997fa5128f7816b6fe2: 1
#   geoloc_327bed8f428a1255844edb1ca1debcc540dae743: 1
#   geoloc_382b3c65d0a4897b1e96e44d78afdab4e3485b1e: 1
#   geoloc_b3a130c6eec185d3e95ace50f4bb271a3be4af0d: 1
#   geoloc_fe3ed754270d8fadbf10db34796f1ed365796e77: 1
#   geoloc_0564602b863ae56111d138baed19c0e7c9ac7233: 1
#   geoloc_6655c63e163e8946c2e3a91baf0a9495900c5688: 1
#   geoloc_74627be6e294bc447fa833345869ff5f1afee5a5: 1
#   geoloc_0171e01dea5ab98e7468b0bf2972d54f0b0fa1ad: 1
#   geoloc_68d8f6b67a0b40f8b2a35a90cc300bc6e00286ed: 1
#   geoloc_7833259c30c783f1e878e93e497edb17df69a598: 1
#   geoloc_7b2b8874f7827bd5bd6a06905694d48e162f1091: 1
#   geoloc_6a69afb61b7a07b4ac14759ee1758257da8880fe: 1
#   geoloc_164ef8ac2e808c3b2a4a4b05949bb0f0d06f1852: 1
#   geoloc_8be32769014732139860028e41b678863797b565: 1
#   geoloc_65cc9fa38a4da210aff9ae278e249f006be5a1eb: 1
#   geoloc_d81674e0dcdfb309b0fe0e5b0e2af8d70034c6b6: 1
#   geoloc_f8edcb796f08bf90fbbd7f5cf1b13a750ebd2cd4: 1
#   geoloc_d018bfdd2aa6821008030575fa79807562e695d1: 1
#   geoloc_adcd2f1f4b902de5ed14541cf49d394c9315720b: 1
#   geoloc_75712032a97f61cdb2f1dd6cf0597386a1e0e17e: 1
#   geoloc_459a23ea0870bd8a9209bf95253cc4af45edaa23: 1
#   geoloc_2fe59c075ea42f8527d738b506bef77370669a4a: 1
#   geoloc_b60993c2addc9742091074401212553e5697e895: 1
#   geoloc_89ffa7a4d9a659ec4e531956ed3f23cf764bcbad: 1
#   geoloc_380107513dbfbd78d1cd8a0509f9873930203093: 1
#   geoloc_29b35f3bdf3605e5f536294ab4238cc4ec0e39c8: 1
#   geoloc_c6c73e400a7966ef60610cdef9fd7ca0b78c6a6e: 1
#   geoloc_f1cf9bd7f0d293be98ea69c122ee896ffc106ec7: 1
#   geoloc_ccec0f5c03b811d9a4eb88ac742565854caf73a2: 1
#   geoloc_3d632b1d6326a50ce94c4dd85ddf11f669444d07: 1
#   geoloc_2745cc6440ffba289d7eddf075b44d0a4c9cd8d5: 1
#   geoloc_bcacb5c831c1d20cebc87c1c59e7225a4ee1e807: 1
#   geoloc_84bcaac52c057d2106705ac60a2be6e275137dc3: 1
#   geoloc_43e4f2f7376966896a0fd8254c5b40821234f897: 1
#   geoloc_f4be8cb4c022cd27f7632ea519c80b4d548dd8e4: 1
#   geoloc_5ff8b298699006e920e21828553da163df061b99: 1
#   geoloc_fe2bd7489031d853e60c6b239ccbbf12dcba767f: 1
#   geoloc_384f10fb7663dcf73af6026c47976fab1bdc3c21: 1
#   geoloc_066384c80d407d0d5dac751cd42a9e8ca9b28097: 1
#   geoloc_c13510e0e80b596e4e2ab63e03c12296e5a721cb: 1
#   geoloc_82f0dfa697aeef03f697261f097ec075788cae92: 1
#   geoloc_7197bbd6c78c7c097a4150c83ef1dc4847e5aef1: 1
#   geoloc_8b91a390ebd776df9f72f241eb41c97920013715: 1
#   geoloc_1dc6183e169331da085ebb953c2e121118f9c07f: 1
#   geoloc_157bcaab4cc7fd19a5655f84451ba30937ba5636: 1
#   geoloc_c99ace441595401c96701b5e058c43a350d940ab: 1
#   geoloc_74757dd3ccee02a9e18b55cd4a5669c22be1ecb0: 1
#   geoloc_17a99d21b93892677fd43aaeaa91946db0c42ee9: 1
#   geoloc_3b5025e08b4a8546cb343b47cae21d7682a100a0: 1
#   geoloc_d9175a568f541048f69b08e9dd51ce62535c0eb0: 1
#   geoloc_ad2727f375aee0a55958c2b1618baa14b39e1f2c: 1
#   geoloc_6dd3442f82cae32d4395826769b165436fcec67a: 1
#   geoloc_7f58dfcec420c8244fd6419e8911ac4dcca1564f: 1
#   geoloc_d788740be5c4820ec3fef92c90499755045a8e46: 1
#   geoloc_ca94f1e84a371e34d0d47780bde11ef317ea36f5: 1
#   geoloc_e732e756836e51193bb06821c8ae64edd39a0e2d: 1
#   geoloc_15d3e4d98860818e3cdffc6d5dc38f464848c629: 1
#   geoloc_53aa091c0e72356c9420f98e8fe96577ca14304e: 1
#   geoloc_c2bbc6910f5e3dd802c3868f7aae860efaf5d9ae: 1
#   geoloc_84dfe6f6fcf83e0bfdf83bf1ae8f2e34539910ab: 1
#   geoloc_048634ada6472cf4b0f5fe82be45a5e7139490e5: 1
#   geoloc_4c190ff6b37dc16c055626b33047b5c55a55ec29: 1
#   geoloc_2ba2d71dce13cb156bae462879d36cee4abc8979: 1
#   geoloc_6d97991206eec188631a20f1a6327db62ac26eed: 1
#   geoloc_1ab94c02623fac143f460e266f6b92eed3285d09: 1
#   geoloc_0b170955a89a130d5505332bd6b51e4b102cf4a6: 1
#   geoloc_3aff087d857d68d4786d40653854d44effb00e5e: 1
#   geoloc_6b5741d9472e631463869e7f5f5932de9dc82031: 1
#   geoloc_0d624d5b06d9819389d54d56604bd2cb02d55c97: 1
#   geoloc_8a5ded6080784656f2f55af3c08a4928ec15a840: 1
#   geoloc_b2f9c60ef93d89ce6df2b220e6796b36826bdcce: 1
#   geoloc_55bd618d196b36b1e4a983f5dbeafd15a5239024: 1
#   geoloc_28b9b2b9dcceb71cf1c5604e61527e2c03dbe071: 1
#   geoloc_b9ac5d3c757780ac1888b3a558d4bfdc34f8ea54: 1
#   geoloc_9895d2d49776d55e8958fb3b9d89e36c5d3c3c95: 1
#   geoloc_d39964fb9821f2958964e4fc807a2941ca8a86dd: 1
#   geoloc_847e65298dd914d7d43b48564fa8e426cfb08854: 1
#   geoloc_35aab0f1ed897ff4bf20e7d5818fb89b767aea92: 1
#   geoloc_23046511ffc05de295a32125557c9680f392e95d: 1
#   geoloc_6db6cc9d7376e45cc99daeecad3aec065ebb27a9: 1
#   geoloc_6cef8dd89f374de9e7570c57ef5f677ac9bfd104: 1
#   geoloc_e753a2d713c013a1addf7f612898c3a250f669c3: 1
#   geoloc_b77051dd5e7dfdd738718ba5da38fe3977944ed8: 1
#   geoloc_8f3797433be9733c85d04a945ec8062407465f30: 1
#   geoloc_2227daec1fbe516220698e08bdfd64bd2c8eaba3: 1
#   geoloc_bb7b1a5da912aabcfbdd5375796d5b6ac3e9b358: 1
#   geoloc_7f85a4be0579590cd6bb7bdfafc5fa9d988220c9: 1
#   geoloc_b3d39475a60d8301209693af93f8ace159cd067a: 1
#   geoloc_c5d6bc39b2c3bc32d416f49239cc61fb9d3c203b: 1
#   geoloc_03859f56425b03eb647b55c01a2252e42921f589: 1
#   geoloc_51e509f8c8d9e27d369d51f1407808f29a44d8e0: 1
#   geoloc_d3988019927dc5fd65c8ff266a4e206f01be2d89: 1
#   geoloc_4d6837fbff2283970f7f90e096ba07af2cd1d5de: 1
#   geoloc_089a1aeb0ee48e50b3169065b889e7e38a75cd84: 1
#   geoloc_a6452ed19f8705c86825c5cfdbbba3e6c1438638: 1
#   geoloc_f19f9026b5fa13e65ba8a5dbef8faf22d03a51bf: 1
#   geoloc_98f202a4088eee532a8be46c45294a3afb2a4f14: 1
#   geoloc_dd66b741d1db64391d6020b0bc42f3824a3ba23b: 1
#   geoloc_c728fe20ede431cd1a9dcf845cf3ad17c9a6bbe2: 1
#   geoloc_057c1e87dd9e0be07dd120b57e1caaee8965b8d7: 1
#   geoloc_4033dce121a56c7f3d894c599f0bf55bf128c348: 1
#   geoloc_db6812dec2822889e85cfc9d523ef8358ce1ce8d: 1
#   geoloc_0a16b8ed1b8927faac985d0dafb8d9d9544e361a: 1
#   geoloc_9d534ff72bf5bc83969e9291440c74bff1e5b16d: 1
#   geoloc_f9fe09522a724dc6ec23b6b57c2872107d24667e: 1
#   geoloc_03ef9b898e946ced0a6b80d4051e9e60865065f9: 1
#   geoloc_89e2605a9d734d9267d29a45f897e978dec48211: 1
#   geoloc_2ae7cdc29cdb5875ca791e5d7d8f7d7a56a4d967: 1
#   geoloc_d2733f8bb203dc1de834a8bdddd8654839d79ab1: 1
#   geoloc_081389e59a4f71f20853080a27053ef3e176a680: 1
#   geoloc_1c2351261a653b9c03f3b62077c9589820455d28: 1
#   geoloc_f752ced4152f5e24fbf791ffcc6ef4950966f07d: 1
#   geoloc_a7b0cbefd8da80032c40ddc04fc34f759ca9ee78: 1
#   geoloc_ce3db545e30973f0f12356dcce62e6eb6d3251b3: 1
#   geoloc_ea3fa43629b4e763e985f308321cdaf8d874efa6: 1
#   geoloc_18162419151bce900136e86dc9f2b26d517698e7: 1
#   geoloc_341664a085df70041462ff1e0caa2bad57c3c3c4: 1
#   geoloc_18dcfb546bea9c88d571e6406308c99ac9763009: 1
#   geoloc_f13a177dd70cea00c81a083a5e0a8b6952b2ccf0: 1
#   geoloc_5c17c3bd4fca598939afd8561ae77448019a2898: 1
#   geoloc_ef7b5237da0bf2f11e232f824abb028b0bef9ac6: 1
#   geoloc_1ef4f840d8dc50c4110b436f68dfe31eceaaae64: 1
#   geoloc_6155b46329a71b9d2c52474d9dd50c6e81c8ae5a: 1
#   geoloc_6fcefd47d8435f0634cf5d0624ae4f42f7d947ea: 1
#   geoloc_9509c6783334a8975643841cfb68cf964c11280f: 1
#   geoloc_b7c98e03296993eab1e13e14d9a57172cd0912f8: 1
#   geoloc_73f49b82b964f482b481999d521dd8a1adf93b73: 1
#   geoloc_70aff0846490bfe0e3f1ce828c9d3d8e85f0b184: 1
#   geoloc_5316cc97e5a7b758d190d881ca61e4396ed80dd8: 1
#   geoloc_56b4ad192f38830c41ee523a2e4497f51741ad05: 1
#   geoloc_97fc9a5c99fe589e1eb3207d221f5ed8caee68ee: 1
#   geoloc_ad8ff43306da66e2032dd5c0e1f92ee404ab02ca: 1
#   geoloc_db65eaf427cac3af927275ebe6c0c05857ff8afa: 1
#   geoloc_46047486e7647cb52855d77809fde3323c416c21: 1
#   geoloc_d3cf30ff30d57e4a26d4bd9945eebcb3b090dcd4: 1
#   geoloc_67e1bf29589829b443e9ee02c8aabb5209572dea: 1
#   geoloc_bc4b18480fc43d4a925ff6d33d24d6ed8ca9e288: 1
#   geoloc_83061eedb68bdd99b87efb305a03a2b1e4927080: 1
#   geoloc_e1b50d957b0507dead817c284790ba44cbebd92d: 1
#   geoloc_32e78dca13c4cc6741379b78d92eb2c47f79418f: 1
#   geoloc_bef823290346d45ddadd101bcecd8e81f5f7d46f: 1
#   geoloc_47b48c53dec2750f2402d544e91c888f4d43b59e: 1
#   geoloc_43f0b9b98cf1e66b0dcab534223d801dd4d1f27b: 1
#   geoloc_bca77ad8ac0f2b03f414313596ccb70ef3cc7855: 1
#   geoloc_53d7a561ba41b1a7f3642a5cdb34e139b34034cb: 1
#   geoloc_1bc1d3af6d4c74ca4ef1d96f9e024150969e4b47: 1
#   geoloc_5ac39a557e1e23a2164d30f31f14e9ec763320f2: 1
#   geoloc_1dce75072086bc795535772bfa90e2db6b00bca5: 1
#   geoloc_1530edc7708fb1e5ab834084d5990b0c824c9439: 1
#   geoloc_f43dab731470e52093b8354e762d103b88679380: 1
#   geoloc_e6a23ef136ac44c212bdda6c703ea01afaaae052: 1
#   geoloc_87805f1e005e64598c6bd36e43e961e30c0af07e: 1
#   geoloc_230dcf0bdb41b327f3cba9e5bc4e1a6c4a8d3135: 1
#   geoloc_dee5e2ccb73054111c6406cb53cf7f1be8e228ce: 1
#   geoloc_a22e210bc5d063d9f16872f969d0de5430eb0d41: 1
#   geoloc_3e2a886563f0047ca5e21fcb31b37f311d5f0706: 1
#   geoloc_13fb362955ba83fe4fd9a6f58ed0f8c6c49dd15b: 1
#   geoloc_494556e3383ebc9c5e37bb84b34a3bec4e8f0129: 1
#   geoloc_2ee8d0d1122559ff11be0df87a672dffdd9b6855: 1
#   geoloc_1ee60aa7f094cf47efef764f0ad3548698276f30: 1
#   geoloc_589eaade5304555922b5a847538ca874dcae64f7: 1
#   geoloc_89b11e5572d249aa4b961b0b33eab3373d908ca0: 1
#   geoloc_d168b992703b5cf6215625f66b7f93c8b00e42ea: 1
#   geoloc_df99750b80b859327ca495a9b4341b4b4d385b36: 1
#   geoloc_3699698be8df5b76971a35b6af4c7df67d4775f0: 1
#   geoloc_746251f5f13a698265e0ff949a72b1ded3be2907: 1
#   geoloc_96b26c22ac312681816d05844f3f2353b11e4a34: 1
#   geoloc_81e935a8c7e59f38a473403ed403244c18a53fa2: 1
#   geoloc_30af0e7f42d1211f070acb9bc8330258b5b902e0: 1
#   geoloc_366c1d8c77ae5d06328186ba69cf8447906ff902: 1
#   geoloc_59f6e2d5e4ad24dd4eef8f1ea306505bd5c5c54e: 1
#   geoloc_a39c616bc573a456f203fe93e1c8a300cb185da9: 1
#   geoloc_4fe1ee43e286d5f05cc59014563c0cff910351a0: 1
#   geoloc_9db11f06194c31e1f6e58cb5e6e7e7f989f42063: 1
#   geoloc_afb1a7b1858654cc027612195bfa91e4c958a602: 1
#   geoloc_a5e8de84eb774631b4a17498bad674174c5b7046: 1
#   geoloc_a4ec3cae3c9e7fe85fc30d3612c4e1dd2ade3684: 1
#   geoloc_be049b24b0f877ba9b923efbb32effc1b6f40fdd: 1
#   geoloc_cb4cb7c15fb78a4df6fc40c3ef72e209a793fea6: 1
#   geoloc_7abd2cc09b927a315d17198d4af512a7d42affe7: 1
#   geoloc_d5d687a0a42d70fe1b7d135bba119b8443cc9698: 1
#   geoloc_40d9c4d99a95435b5279c9fd7e75964a56190fb0: 1
#   geoloc_ead181864eecafacfa812a40f6648d4207736f59: 1
#   geoloc_1da2a1ada98ef7a87907fb71f464d592a028ea68: 1
#   geoloc_ba057c42b82db285ea83240c53d4da2ba82bf646: 1
#   geoloc_b4527ee7ef590c7abecd21419b6689ad37121fec: 1
#   geoloc_26e7c04f4ca7bf88cd072e918166d5b07b566ea6: 1
#   geoloc_4cf53aeeb12d399961034e914cb6499962528c62: 1
#   geoloc_60c6e442b03d12c3686c0244c75bff37c01caa39: 1
#   geoloc_11ddf606efad8b1c1cd661e208abba8faf34038a: 1
#   geoloc_20b14351ebb4b7952c9c8323df0cff1a03cdee4c: 1
#   geoloc_a1647c49f6999769db887062e76cfe7c72026ea6: 1
#   geoloc_22a6a99534e525eaeb4676aa93a9c05b24888f45: 1
#   geoloc_a1292e32882c1c477d6ef5245316c3aa9311febb: 1
#   geoloc_407a612b6e1f4f7c350580cf38ba8a0b0210904d: 1
#   geoloc_40a27ea0b18472cd103bd3695b23305b24e0eec7: 1
#   geoloc_fe2cc2a7de62a33e2f4501dfd9c968e86e724741: 1
#   geoloc_611be89284ace42d4f38386723e3c36f25d27e9c: 1
#   geoloc_38bb4aa35bf53e49363687f398cc24e1d0218713: 1
#   geoloc_2104c0e3b50aa5a38d2578b322ca767c2585cd62: 1
#   geoloc_87a3eeda073343fc9a2fd4e977966982ba00c6ee: 1
#   geoloc_6ce20a3e2e431f6a5dadd93e20a4c778ecb588ce: 1
#   geoloc_1c2b9c45ca55bf4d1065843be524ba79143c022a: 1
#   geoloc_3c0ad4a0e13943f9e5298b2311e35fc1a386d1e6: 1
#   geoloc_c61e22664a65651cbb40ab4ffe204655a89966de: 1
#   geoloc_7c827c766bacafedd0c076f567c23c87efec14e2: 1
#   geoloc_28c601d50f52c243f36e81727bb6fabae31552b8: 1
#   geoloc_86b915fe0e92ce1f18523b6f9af775b5b3358d31: 1
#   geoloc_49e632260b2128a039f69da117127381f0d532d9: 1
#   geoloc_8aed8ad441ba181ba6ab5c0e798894e69f6b5ab4: 1
#   geoloc_90c455154e5038be6730ee9e408208842f3e22e7: 1
#   geoloc_2bb2f2ef6b5709d8d0e0f80a89410c387724fdff: 1
#   geoloc_35ccf74a3b40139433f4ce67d81f849d7ddee20a: 1
#   geoloc_8449046d1e330c22881b7a1a2d5c4ede8167b6ef: 1
#   geoloc_851104ca244eb0fd43c7c0c14efddc34e1db94e2: 1
#   geoloc_0bb5a156d04df746fa9afc5a798d1c7c88a360a2: 1
#   geoloc_100563b60193158a2e5ba3966b06a1b6173a72e6: 1
#   geoloc_3e6b044cb4518a14f481361e2a6c5f712ffc4d40: 1
#   geoloc_a26970a165ac37fba0265323008014fbbbed5648: 1
#   geoloc_db7d8808932614006e8bf2687997bec37208bb03: 1
#   geoloc_318abb2f8029d2fceed6dd75c6213c6ae908231b: 1
#   geoloc_89333911c7359bbe74842d39a8e70cb1e326e10b: 1
#   geoloc_3519796e5c8676b11c9a375cffc1c4df07b5f347: 1
#   geoloc_777972d8c76ef51f9431f3c5bc7c2662345a3ec5: 1
#   geoloc_217e4abcfcb2830b7fd1b9785bd314024950f0fc: 1
#   geoloc_c4a6bb6ada7f712d30d8eb27d47274aa5ee12d07: 1
#   geoloc_b57ee2c638377fbed45ec908bad135129937e42c: 1
#   geoloc_af1c2a8850a7b405ad12af6ac6b11b920a343dc6: 1
#   geoloc_52dec71bd9017ab46208da81b979bf9dc364ef9a: 1
#   geoloc_dde7731bf72cdcbda176bedddb200ab0698fb228: 1
#   geoloc_50d65e68a3f3f294c107a14c3f7a6d3254ddf3b5: 1
#   geoloc_e4e95f316f54300f522223b55e9526b7126ad213: 1
#   geoloc_8ec39779480cf4109e2121472e3a80802af537e9: 1
#   geoloc_425549ad552b3bd3c3718d73215d2bfadc09951a: 1
#   geoloc_2fea44cdc573c3effc8cfcf72c7fa00e1107e635: 1
#   geoloc_7820a0ddd952ca21ef55eac7810fd0ead8781541: 1
#   geoloc_1b40308163e4360c5e626e9883114ab73026ce3c: 1
#   geoloc_97b813a687c69bcc746a1add86d681c172edcf47: 1
#   geoloc_ccde3ca6010095da46cd2e3c76ea3b365f31130c: 1
#   geoloc_37336580eab87d5797ed402fff2cf60e8611eeed: 1
#   geoloc_5ac6ee4002e8980b00b10b32ce540ace2bc9786c: 1
#   geoloc_c0624aaac50c6e4dbfcce862eb21d0a362bf81ed: 1
#   geoloc_272aa79e529a0d60099cee16efb86703b11052ac: 1
#   geoloc_1e5128214e7db5d528f36de05f25e42159fa6afb: 1
#   geoloc_ca21fd1181df2bca9c0d33ed94207502a57b3711: 1
#   geoloc_b5a36e8d2646c60d8a55edf379cb2246ed643a7c: 1
#   geoloc_9c3362c727e43a0663a9725166319c13ec493148: 1
#   geoloc_b9671821dcb600a5f1314fd0d7270a5d44fa5ce9: 1
#   geoloc_4f8596109a12ca9b2e245ed48ff2ff9430e2cee2: 1
#   geoloc_dec261c98d0cdf86a8781a0c4fa7c8f0e53e161f: 1
#   geoloc_7624ffc23b9b61485314d3b1c74afa1ebb4ceb32: 1
#   geoloc_8b9d182db2fc0bf741dbfce532be98b145a1d985: 1
#   geoloc_f4c0c74fa61f8d197bf79616ca1f5354455e320b: 1
#   geoloc_880ebbdb7b1133941e5ed84226af922eab598c4c: 1
#   geoloc_b1ad8050a669e3baf7f9b39362f1e38f227f85c9: 1
#   geoloc_a9c71124a2b9b093ae76771cd31fe07bd3a551f6: 1
#   geoloc_2ad6d9e4a426c50ebab4dd474431640d8f0fbd13: 1
#   geoloc_161bdfd2a1fa66eaf0ffaf01235963b8d184d9b1: 1
#   geoloc_2bc6148099607fadc7a8fd93ff932d27a001fa99: 1
#   geoloc_0c820100a5c5c5fa3a0bf6f1e77315326d72208f: 1
#   geoloc_7746b07bcc22598931c3cbe6f74cf46bb1739712: 1
#   geoloc_91c9ecf20f72bf6983bbb4e309545959252691ef: 1
#   geoloc_1d617cd655c784ba70ac45454f11cc9f678fd1ca: 1
#   geoloc_f0204d039dab3e228653cff0bab4cd48a60b5a3b: 1
#   geoloc_f9eb0641e76ca993b2ea0a0613fe7fa89293a093: 1
#   geoloc_aaddcd4035120cd69d2158302eb72b5caa6b3d7f: 1
#   geoloc_f8b281e8d04098f48f0bf2c1bc62438004f8645d: 1
#   geoloc_743b2b256b62a84a3ab0b9862cbd89a3068126db: 1
#   geoloc_40fcf584b4729d78702233e633b7ee763ecb3e9d: 1
#   geoloc_2930ac7b70987e96e5c7aa302c7142d8cc1a847f: 1
#   geoloc_0639659252c7cc9b6da6f5ad6fca965f3160fafa: 1
#   geoloc_e3b7b9793fe776897269bdb7aca15b735aff48fa: 1
#   geoloc_1602604e10a46178a250c44500ba8b65c77af2a6: 1
#   geoloc_247b78f08404c2cdbcc9ca72d73b73273d04c722: 1
#   geoloc_fd1d2285cfb6601a0b273fb04d62c3f52453e920: 1
#   geoloc_ef5d041bb2cab0f234e3d27383186dd234716eb2: 1
#   geoloc_90d912da47280f238d0bd002c8cf804a1371d50a: 1
#   geoloc_08852f0da444daeef3f65b736cb39b725f8459a4: 1
#   geoloc_71de9cb474be4590b8f95a1a4bf9c6a94fe17c4c: 1
#   geoloc_f6c82f6829e0a97d5e1feecd0e03a7ae68f289fe: 1
#   geoloc_04f32190c459bb33db9e262ebbbe9ac582b7f739: 1
#   geoloc_f436a551f6d615312003801f9d832fd7cd7922e5: 1
#   geoloc_2d459eff3d54d0d020e9aaa9192b849bc7904eb6: 1
#   geoloc_b7f2c335c0cc10c564175adaed5446cd874feab9: 1
#   geoloc_f28b3acc4052ab757029928eb59e124e411c052c: 1
#   geoloc_0b3402ab0f73f4f957ace740bb08fa296b233f4a: 1
#   geoloc_0bad73e27bbb8a17bb49b1b9e1d8cf5050d626bf: 1
#   geoloc_8526417efe0cc45737364fcab26b50cd58109573: 1
#   geoloc_d8409b3436b9de8155a36886d5c0af67a6c832a7: 1
#   geoloc_66f56ba3f786d4d50927c288f4ef1603cf51a8e0: 1
#   geoloc_112211d801504da880a25c4b57929cde791bfd98: 1
#   geoloc_15a067c682ea876124f1885adc84fc7e28c47d6c: 1
#   geoloc_23e2ad9c313353363177a634b4d3b026d16a2e04: 1
#   geoloc_8231898b9200d92d3c127f0b3ff6fd04327a7729: 1
#   geoloc_c0538420f0dfc6599f77ec9f90515372ff86e5f5: 1
#   geoloc_c25d2ff82c10429708b963dbf2676d57f0dd35e4: 1
#   geoloc_ae34e91d3397c8fe4e5b805a1425bd182268f2c6: 1
#   geoloc_cbc6dfec40e71635e936f8ea1ed56d635cea39d7: 1
#   geoloc_bdc2f5378cac4e5e53432a1dbd554f1ae20ff26a: 1
#   geoloc_16eae9d1b763d1ac07234c41b97de12c91437578: 1
#   geoloc_4de644700842a5eec8447bf2eff51c8f83389a91: 1
#   geoloc_5836925db6c10ed9b082bff661a7339eb2cfe182: 1
#   geoloc_69c3c9215cc321ba11b8d23a7602ed3994e5b21d: 1
#   geoloc_6b0d53be2760c60a89889311cf8a5ac52072a197: 1
#   geoloc_a6e49d04043ee6c76bfd99def55baeb1860221c6: 1
#   geoloc_e2c247cf7bfc2bccea50464b9dd3206caead36cb: 1
#   geoloc_1a8b8af18c9eaf8f19a3a1d91a2be6da84717777: 1
#   geoloc_a7d2d0b3634b698f1f77d723f92379f9a03bb3ee: 1
#   geoloc_c32a68dd9d3660fbfd3db71029b6e53d1edc9a18: 1
#   geoloc_31d348580cfbe738bf28d070721fc2978eb56bb5: 1
#   geoloc_b4f151cbba66f92313f219f6900b7227a1e86481: 1
#   geoloc_b230cbbe8d74b15cf82c9ddc1ecdc48e526b18f0: 1
#   geoloc_e13c6886f41b2accaa58d055f39545889dd6776b: 1
#   geoloc_34abc6e00619310cc4519abafa134040b6eaef4e: 1
#   geoloc_73ef6cf1fe8a4d1590cbd17ad4e4e20c827fc0fd: 1
#   geoloc_b4c7a29a844486b04e726435a996597737adc11d: 1
#   geoloc_24bb8aae9140baee89eb2c432f78ba16879e4bc7: 1
#   geoloc_8e3bb43b946bf71b4d498a56a9ed15b6bc27014a: 1
#   geoloc_12c8e4b8785bea5637e9170487f1d5afb41ac407: 1
#   geoloc_d601e1d8f31ac3c614c5d41ab6737e9ef47f1cf7: 1
#   geoloc_044f5ab3be9738d074fc665631a05f77b27b9e77: 1
#   geoloc_8f629c7bae7e2ab5ed039395ff31362ec302dca7: 1
#   geoloc_dac905bde04fa168d5d6f3ab2955fec71581f008: 1
#   geoloc_7246a851ad7970aca0f81edb6ddd074b8f6630ad: 1
#   geoloc_359ed1296cf6213256dd0a5b37c43e8bd2d76316: 1
#   geoloc_291678a6f41bbd13fa22771eb20ae290e37e07bf: 1
#   geoloc_5451c67fbcbec57434d948147f5bb5e98154d122: 1
#   geoloc_56bd3520661b6f53b8379ffa495331d11120a1e4: 1
#   geoloc_38ddc88d0e2e5883a5c76d6e5aa5b27adb917126: 1
#   geoloc_f29864058911d6755f268619be3fda82770a7a7c: 1
#   geoloc_e04b8df0b2e68e3f4a553cb7f97003bb629a61aa: 1
#   geoloc_33ca78f6dc95b0487b9420e5f1ee9f21d18047a3: 1
#   geoloc_40a8a5e3032ce474862b5e9aa5523d48bc761d22: 1
#   geoloc_5ccba80bee6666f85c87d5d86ff7397826eb26cc: 1
#   geoloc_a9e570eecc915ad04b0dbb05488792814feac927: 1
#   geoloc_b98f0658a5815d8e9630e07cf0484321dc08cf97: 1
#   geoloc_106e2d3a93542c23b9513dd74b2d92c1d63659e8: 1
#   geoloc_ce23e8b96249f68067bc337002b558df9a229ade: 1
#   geoloc_5e3cca379f254a5a8b99deb28ccf989b54494bbc: 1
#   geoloc_22882f290b7b6a1c52f69db006f5b6d18519597c: 1
#   geoloc_55c197d90a366084560e3f92d8c3974ec646a943: 1
#   geoloc_16a748c1ce6d79bc63a6a6a06c213666f4a7008e: 1
#   geoloc_c13e143ccef463f0ce77c0ef0d2e7136ec0f7724: 1
#   geoloc_cc680df6c912f0bf09acbcd35c105feaf0fbeecc: 1
#   geoloc_82d277033cdc57fe316e14df72b013191c47c2d9: 1
#   geoloc_b94d99c3d61d468c7ff9a403ee57e3d5a1aef8ba: 1
#   geoloc_5da9f321a9347521a73f782dc99a2b8252ad8eac: 1
#   geoloc_e68b93eef2b1cc17118b529764ae60f4d65c9032: 1
#   geoloc_b41a2959a0cecb4be7846823db5a15550424a7b0: 1
#   geoloc_61f16cdcc3343bf8f141e38900a270710f765d71: 1
#   geoloc_eac9de5ee5b4e1c47925eb9380485bc3db650f5f: 1
#   geoloc_d5cb06a9ef20aabb5907bbdf0009491c7254d3e0: 1
#   geoloc_01f745c642b9c039c25ee5b48042d630340a513c: 1
#   geoloc_a3f73020567ef0a426d9d29fbd3de65f95659ccc: 1
#   geoloc_6b5eaf6b14449f609b21560e8723aa75c5a8bfa8: 1
#   geoloc_c18478bda378cf1c48c1937e516015361e597701: 1
#   geoloc_4b10cc1d1911a3526c9f60ce47a64734d5cf5627: 1
#   geoloc_44014e1ed2dcc4ba00ab08c27a7adfb9917cde33: 1
#   geoloc_253056eb4b48a3e1da30dd1bf71c966555574ab7: 1
#   geoloc_5a466e7552e69110568817d38e84a3f770593b67: 1
#   geoloc_1cd244a5316e2680f2d2a7187b7b0d5b8a9a697b: 1
#   geoloc_8da9a76ec06b1cd371ee5824efd0630073cefc9d: 1
#   geoloc_af5d9753687924c0572fb7cf512bb897c9d80e38: 1
#   geoloc_85a908e56793ab1c2e58c53bb229f9718d409421: 1
#   geoloc_c88b7e1dae2a9e98a6a5597e52727ebd06d5e883: 1
#   geoloc_512bcc3b191f5db4c3043ea70418489d820afb2b: 1
#   geoloc_bcc0f67197280d0fb720aaa46a71581076a14b6a: 1
#   geoloc_3843563208067fdcbfe3d80c8908997e7ba45baf: 1
#   geoloc_df032c79b9a3386394543a30427c526fc0332f03: 1
#   geoloc_a8c2ca0a4c34226127bf3414c0d972505c746def: 1
#   geoloc_63371c19c6f29e8050e89a8ca5fb980eca8d73c0: 1
#   geoloc_c794dfe8c4174c25df108983c5bab2c83f6ec02c: 1
#   geoloc_09b075e3ed83c745074003661d311ef93bc764c8: 1
#   geoloc_3fe03139d90acbf33027cd88506914c0dcb33918: 1
#   geoloc_6eb71ae4d090b3dd3a2f31a958237c0781849f16: 1
#   geoloc_bfadf8bd7007129180e8158a598009af2ef561f7: 1
#   geoloc_d8cb952710054ce2f5903e38a4d31a4d2ef17b7c: 1
#   geoloc_d857bd78b548f427c12479e0df0920ff070dde9c: 1
#   geoloc_2fe91e58238b42601f3b6acd599e2d89ad63a3af: 1
#   geoloc_a307c18c4f5b043b9cd6f487cccae4506c537fab: 1
#   geoloc_d88c8f28379dbf03f48b40277a48d5889724ef71: 1
#   geoloc_893f13a32572585e7e12636e7d5912b146a3d3ba: 1
#   geoloc_e737162b31dbba63d673a132446f591fdfb6f4fe: 1
#   geoloc_1c052bd8d3eb019cb7a35783acdae1f798911570: 1
#   geoloc_b0f2c62e3d4cb375e81fb05c81976917d6275ba8: 1
#   geoloc_71cd796aeb75c36e010cd6767f98f81d9aedeebb: 1
#   geoloc_ef76ea30f751e508fc3b3d84e2cae9dd52c744d1: 1
#   geoloc_86ff877c4501683b99e99141d6ece21f034135e1: 1
#   geoloc_7f8cbb69699266fa6afe4fb776cc9480e73a0b10: 1
#   geoloc_4fd39ad6058e9cf7dba5ece0d61f35c4da625e2e: 1
#   geoloc_4d5c55b3732c14daf3dfaddb642f6bb32b9fdc65: 1
#   geoloc_c89668ed3eea42b5008eaea8b05817307a2b6b4b: 1
#   geoloc_8c531fd3dcac7f5c3c3b71138003bc4c69ce38b6: 1
#   geoloc_5f2cc57b69539c529131148599b9e0e0fdd32666: 1
#   geoloc_8866e962c464b17d7cf6f26665f4f4cad404e74d: 1
#   geoloc_eb388fcf720f80d88e5cec913857b7a6c7433fde: 1
#   geoloc_38d4f8cfcc11a7c265443ff370abf9943acf7e0c: 1
#   geoloc_2dfa14b444eb0ff335a32beab489c81c43741dd0: 1
#   geoloc_21bd256d1790e38e70c165692d099164c637feb3: 1
#   geoloc_d88a67cc5a6507d16bd8dac5a26b557fff29f1ab: 1
#   geoloc_f6bf87c9fd05ca44711046c09c9c5e4dd061b973: 1
#   geoloc_94a20881850f5d970e854f02e2f997ecbd5f727d: 1
#   geoloc_4df7dbde36dff13bc69196be5e2799bbe08587b3: 1
#   geoloc_ef71f51e8919f0e13f90118ed2e04d1842b4aef8: 1
#   geoloc_3bb3c33fa792ac1e3a4190d10142d64bf278f616: 1
#   geoloc_a0f07685e5fecb8bb2c285fffe674c721f032d78: 1
#   geoloc_426e7be43cd7657f8450489689b13dfb61ff1491: 1
#   geoloc_cfdeb731774d3d6f13434db6127807b80774d26f: 1
#   geoloc_5733e68670f60cb11d525980ffbf6c3685fa6187: 1
#   geoloc_e0e18d5da075294492505c933b601c23a3285d35: 1
#   geoloc_52a2faabc7dd3c6e3eca490aec0185503822f67a: 1
#   geoloc_bf3511a3930c052b8b9e9c6d7474e9ab80fbb12e: 1
#   geoloc_6fe4ff0bff27ca8176854b02b3638b9aa527fd6e: 1
#   geoloc_47646cef7461d16df7dae1050f940b643e203bca: 1
#   geoloc_bd3bec5deba5546611519eb807ce052ac80c1b95: 1
#   geoloc_2f26392ad6d98dc9f5048a0b337fb3ed3b544e2b: 1
#   geoloc_f29961942bbb69c7ecb844c127e61553a8bbd39b: 1
#   geoloc_47c51050dd1d8a66b90cbc4a1d4a62430b796ccc: 1
#   geoloc_7a333a886f5d3f8c1e7794189da5d4e1cfb16eb6: 1
#   geoloc_fd5b7ca88d3e410618b009430dbb960b979ebf59: 1
#   geoloc_99acfe7349b959eef874f0524d52f8159283bb46: 1
#   geoloc_df90d2dc7754b0007847c3a2c694165fa359c092: 1
#   geoloc_adab400393a73dac8e5963e6db2662bcc8c6b697: 1
#   geoloc_cb62d9c418011e662e84a30e0097b1bf2b24d1fc: 1
#   geoloc_54a8cfd075ec6aae6ca32f6312ded8c712e4266c: 1
#   geoloc_aafb00924a2be577f0443454ce3d909961cb8fde: 1
#   geoloc_883da1220745044c7e91a601e3f6a993e8b8311f: 1
#   geoloc_cd99955dcd188d17af8f1cb1c57049999f508afd: 1
#   geoloc_4cee826612acef2d1297ff5f2a459b7c0d0befe0: 1
#   geoloc_5cec04193fce021d2435bc54c05e3daf4d8a18ef: 1
#   geoloc_9459acb433bed7ea8100c98728f8f47fdbadff96: 1
#   geoloc_161f96ec755b0cbdf1adcdb712c6d41fa5827554: 1
#   geoloc_c94515e37ea20fcd36cc4a9dbaef471a27ff68f7: 1
#   geoloc_2380486bb81465b978d8ca267041f813fdae91da: 1
#   geoloc_f01e1f8110433bd6b50553d4bf871e45094fced4: 1
#   geoloc_93917f80a3c86bfd41b925cb5338ea3f0efd5f47: 1
#   geoloc_d16bee6cf29e2a3d9820b04cca44be5a114cdff2: 1
#   geoloc_b48a5b65ef96d01bad62d29a4c82ee3977033842: 1
#   geoloc_ee1cbce603e34afc39989ced5cf22bfb8430abdb: 1
#   geoloc_870b936fe66a6e1003ffae220d389df296d92009: 1
#   geoloc_22971ca49d1284f214133938ac416336fac249ab: 1
#   geoloc_a54d977b99b92bbcad56b92041a6024e8db0a7df: 1
#   geoloc_25ec40408479c6b5d0cde5d1bfba44b32669d6d4: 1
#   geoloc_b31e35dfc6dfa0277d856dbcfcda7ce4d4196337: 1
#   geoloc_5b6018a09e58a0e376e13092b9f91e8ec1710824: 1
#   geoloc_90da2452b776f5dd9fbeb5e89a9b36d02a17798a: 1
#   geoloc_ec61b873a828c0ee841a6bae5659a93e37e4ef7c: 1
#   geoloc_440f9911a2f110efc7d112c87a1e15fad9cee1c3: 1
#   geoloc_3f2c7e12f9dce36dc7c58cb0b5659df2f85b8722: 1
#   geoloc_0553857157e25e29fed77787980b01dc10433ca5: 1
#   geoloc_da2ae0606db413ca19b11cb34948e6e554666bd7: 1
#   geoloc_9df682fb9a9d73487e7bdef782099820a1c4d335: 1
#   geoloc_488fd2ef5423fbf27857d3e417bb252becf2033c: 1
#   geoloc_0f544f0d11e2445d992c0b9e864bf9750733e57f: 1
#   geoloc_f7c773f538c648b919e7b0ae898467e0f46f2ab2: 1
#   geoloc_cfe02a25a17e8e5d679afb0e1d6e5c0ca3e36c6c: 1
#   geoloc_b498d84334f11202cdc6f2589d6da0074b5e1c03: 1
#   geoloc_3c8f6bea5193a6671a9ef923905b0a4b1e22cb24: 1
#   geoloc_b289baceb4fcd3ced053c34f87a86ce10a06eba0: 1
#   geoloc_92a3b9b8de0bdc948889d25b7e12c1670b040984: 1
#   geoloc_19e12e19fb3f8da4d2e7a084dbda9746b99be9b9: 1
#   geoloc_e17ce66ab4cc51ac46b658384759be454c52649c: 1
#   geoloc_fbf2ce1bfcf61ccaaf88035e846a63369037301a: 1
#   geoloc_11d91802d0a0bcfb8bbc268ef55dbbe0358f5394: 1
#   geoloc_3c468365890d29bb55bb6d6acea0c8cedf55072d: 1
#   geoloc_a02b6b17a271e85c71106cff2600fcadc2fd35df: 1
#   geoloc_6bebeec7a2148ac141db1cbe5bae3d67474e69c3: 1
#   geoloc_a615121b020e64105ebce0c56db85f0f7d682302: 1
#   geoloc_87763a0506f63c99d9d3caedd03b7866afa6ad91: 1
#   geoloc_7fae93f6162a1db79a1ef2887e543da56dada515: 1
#   geoloc_5b46abad1e93968adaa62a70802703830f15765a: 1
#   geoloc_6221b1140fa8d3b3b490766bb1d39296228d25cc: 1
#   geoloc_03ec13c322822127f1d8bd2227f6b419b0e9d35a: 1
#   geoloc_54decb7a2a28a034aee474d503384b202ea5b318: 1
#   geoloc_3df27ca0c95c4a00ace592d33f9018b33dab19bd: 1
#   geoloc_591f90fa522371da08cf029000c3c6234f71a586: 1
#   geoloc_3c1c1e86b76392f2e5802ba2290119903ad1e74b: 1
#   geoloc_82805feb08ee786157cc172f0babc548286604ae: 1
#   geoloc_13b3477b0c9aa2216aa005efbe84b6e0b8f2f011: 1
#   geoloc_bb6e32804d3904d825c7890268454b9de58b01f0: 1
#   geoloc_edc3632dd316eeb5be21a7b19c8bdd3aff8e0b8e: 1
#   geoloc_5d0f94730e1f83f76a51902369cfc91cefa47fc9: 1
#   geoloc_ed82c67e6d6af9552933bd9465c09aaffe06f5de: 1
#   geoloc_c19d92d878a32eb4c4d6df45e0b0ae392189b711: 1
#   geoloc_bf3365ae54751d3ced73669c25811652b48ffe8e: 1
#   geoloc_45d4b9917936d40912fe33dde21b03a1a03c12df: 1
#   geoloc_d7e18b1bd4ea8f3ba8d73d611b42d49a2baea00e: 1
#   geoloc_07b39b90945d5d2587ea4a99fb3c516866466227: 1
#   geoloc_a4be4b5e71210f5427393c0fd5dd4b19cba7ac0e: 1
#   geoloc_a3e8771ecebf0b7a80ef9546b6b563871e442cdb: 1
#   geoloc_7ced643783cc51acacf33a1eae2ef2cd8494a79e: 1
#   geoloc_a9432f34d7f2875c0f4332dc0b9dd841931153aa: 1
#   geoloc_35f587c480282772fe1ed65611e778e16d9a6cce: 1
#   geoloc_f2f83932665e2d7160dbf62287208466b3e19fc3: 1
#   geoloc_d4abb604bfedcf22bb09384deaa109781e9929f6: 1
#   geoloc_12456fb46efbf73167fb9c046674c5fdecf73258: 1
#   geoloc_2da6ab5603b24f4bea33a2d79c11a95e20e12567: 1
#   geoloc_613f936275635bd036362b4f4dc8e32691423484: 1
#   geoloc_a6e08bdc8e826b99bf4ff47ec27f1217b7879058: 1
#   geoloc_05d1296ebf33c7064c3be149f9199721ae6ef087: 1
#   geoloc_6b880328584d18f954c20284fd74b4d8dcd77d84: 1
#   geoloc_bbe8fa53f718f52cadbaf9f9df888d6381d61281: 1
#   geoloc_64de9f90533a5d991f8e400db3232a1a82bbd2d3: 1
#   geoloc_4c104063100c8b51fca8cf08e9a3b976da859156: 1
#   geoloc_da5a5a020a29303ac8af906511fcd97ecd95de93: 1
#   geoloc_eb85d3e57dc622101b13d033230106180724601b: 1
#   geoloc_b31171500d047c71f92fe501d63ccb818967a029: 1
#   geoloc_dc53c66453a3d397374293a25ac9cbb1926442fe: 1
#   geoloc_e2ecb22b4871bfa6293bce1b0281924992d09f1d: 1
#   geoloc_fb39ec78574362bc442bb19f8d86764c3501181a: 1
#   geoloc_b160991022e1c77cc21182a179d3b358b7ded8f3: 1
#   geoloc_2108d9ae81d9eb01c184d08fa06a4de889a9fee8: 1
#   geoloc_47148d792e56d20a1bc1e37b3f79003c3eef8f2f: 1
#   geoloc_fc354d419d4f919c04c41745561b97bdcd20757f: 1
#   geoloc_1195711ffdc4529226e06218cc7cb6b0deb3c16e: 1
#   geoloc_ce83067d67f025e5096e2011913064af7dd4257b: 1
#   geoloc_0a6295ae0eb5bf4bccac4d831e5bb4c009b7f54a: 1
#   geoloc_f65eae4a19c2ac21b89d69738479902446aee79c: 1
#   geoloc_feb0d65b291e9f990ea5742a2dfd1313ded51c34: 1
#   geoloc_41eded1c30413ec682f669a4ec1158286552c7d7: 1
#   geoloc_cb7728a827151248900a1dbbf3574e9a7be62c8b: 1
#   geoloc_d510ac9b7271b8fc609f8a021964e569dc347fba: 1
#   geoloc_51d0159490a229f81b6a507ccf73d476749e249d: 1
#   geoloc_179ecd250a2ace1710defe4833c8de4e968edfee: 1
#   geoloc_624ccbdea53d40e5a8312cbc1c53c948b5d2ed01: 1
#   geoloc_ab380683e3059d6e66430ef050e5fc5b6d2142a5: 1
#   geoloc_44be7e714ca74de36c13f0307e4faf8c8af51310: 1
#   geoloc_a86feac8135560371a8f107c51556d7c61073836: 1
#   geoloc_ce823d61813bb7d330078693a71aa55d6f18c081: 1
#   geoloc_7746b5063e9d93abe176dc940dac03ac62329460: 1
#   geoloc_84ee7675cd1870e7f925a13a65c90eaa867f19f9: 1
#   geoloc_0d375aa180ba08e862e2b5fd4fda0b22923dc5f1: 1
#   geoloc_10c1c329729636dbcb6e735e04c1814fe2a39526: 1
#   geoloc_4dc546fb550a561abca902a35be03d5b90dbb124: 1
#   geoloc_0ba706c33d630f11348886c7d2bdbcb214b18b9f: 1
#   geoloc_02e68c1a39f5039afadd76905fbf6e43995f59c2: 1
#   geoloc_828ba01d82770a0b9d0b6841b4fc755f0097d23b: 1
#   geoloc_cc714d7996415cf38adf3f62935df76c46e267ee: 1
#   geoloc_27cb2304498e1c36271537d5641e01eebe54ae6d: 1
#   geoloc_3d24670509e9eca322444060545ab7e44d91d089: 1
#   geoloc_59ef12645c16c510fd06149ff7aba6f4205e5ef3: 1
#   geoloc_0999fc53feba8b6e5f8f8163944551ffb2ccdbe8: 1
#   geoloc_754cf1761d4af95d323eadfa9da2461c56a43519: 1
#   geoloc_bd61077922f70f53993207e3e730bc079672a496: 1
#   geoloc_867fd3fc1a29c8d8040cac19b0b84f3653e91167: 1
#   geoloc_1502b3b98968b1adb4dc5a619ec99b7e9b8460f6: 1
#   geoloc_911909e88ced54328513d68e546e708daf8b44c8: 1
#   geoloc_949fe314b3eecd003c0ecf06557c94fb6df0c176: 1
#   geoloc_d5e868e17a1bf6652ad23268d1a4399e724470f3: 1
#   geoloc_2ead07e4f0b6c0badec961d8d077d15dfd08c87b: 1
#   geoloc_758e1ada6576850e74965c8931a82593ed4a4cd6: 1
#   geoloc_fca6a696a66c0750cb43e9bc3a4c0858ed03181a: 1
#   geoloc_53142f9b9c8db07f54e6a9bcf00f3d8ff947c56a: 1
#   geoloc_d151e3abaa7c9928e4c28bd2b82e96ddecd85aa8: 1
#   geoloc_2b6e9adc78ee6620d6adb7d6b98eee556ea792d9: 1
#   geoloc_d6d3c900e8195096573fdcfc4024eeee2c29161f: 1
#   geoloc_b220718e0d9e9760d88c91ccff8683a197f72b87: 1
#   geoloc_585de9d55885bcbfa39ef913c0f14314e7178d26: 1
#   geoloc_abf3c3b47241d25ebc1ff5061f29ed19db85d645: 1
#   geoloc_4d62f539aab72899629972eb5c3c90856afbb837: 1
#   geoloc_a0d40a7980187b14729fcd3caec8c77ae2cca673: 1
#   geoloc_ceb65b4180075992cb76415d9122d3fea063246a: 1
#   geoloc_bd3dfc9c7749c5f3eefa4ae1057cc957da38689d: 1
#   geoloc_3c02f3b0a7febf15cb1bbaf99217a3b5dc990d50: 1
#   geoloc_3319b037a16380c4ba9afbc2a0a6993c072b0a40: 1
#   geoloc_e6974cc8b6f572341b490704c3df47cdb67efc1d: 1
#   geoloc_3a87c1f94c726a665856e7dae2e6dd0bb7fb82be: 1
#   geoloc_ef40b372f283a46fa97f7ebc3f168a9208833ff8: 1
#   geoloc_461843a2994ae7cd06652fa1f21fc2052c5d69f1: 1
#   geoloc_bd6a62c0658dadbe3e92bae7a98e05d95f0c0f8b: 1
#   geoloc_20e24997dfb8470bfd6bf9895a46bcf459e75215: 1
#   geoloc_09d92c0265f6b384e08320e6269ab57873cc8667: 1
#   geoloc_d4234b32aa25492670747ef1bcb594257e317d27: 1
#   geoloc_63b33aaed474f10c064b0977c8d9f8bc906ee2bd: 1
#   geoloc_fdbc93c6b540bdaf7fea066d7859c10f30c8edc1: 1
#   geoloc_0e6d2e2fa2384b07765553c5a0ff77a99d077526: 1
#   geoloc_c0a074880fb2b3b9aad7662ab8ab1c6bd70ed6dd: 1
#   geoloc_607c188b739a145f3262c0282aebe9b57c7af14d: 1
#   geoloc_34c83dd2975478abe48cdd4335e85974618409aa: 1
#   geoloc_eef900137c263fb417f54ea281fbd7da5b5b05a4: 1
#   geoloc_be4723a37ab6e5a092114abf972c65141079974a: 1
#   geoloc_090241055bbf5379a0d16b944204625aa6897b6d: 1
#   geoloc_bf8ef5442bec7d921f798facca2a100bd9ef6f51: 1
#   geoloc_34d6f2e270dde755d1ae7a055dc3ec815c838414: 1
#   geoloc_6e0c2ab41654158d528ba418ee6c97af18c5e334: 1
#   geoloc_3c16363c22b91dd6365f9fd17c8faf03f091001c: 1
#   geoloc_2133310cffdc824e3ceb886212d2c4e30c4c6797: 1
#   geoloc_fd2a4fe6babcd5fb7f6ace0abf1eb53c60175a92: 1
#   geoloc_baf1f10708563d0428982a8089273cb6dde557d3: 1
#   geoloc_7c69134f69dc7864bfa252745aa39b6986fe1656: 1
#   geoloc_07a78bb6b20b26c7cf63f90176ec42d6688519fe: 1
#   geoloc_ccfda2d63191866ce8f8d3a2bc9ae08e9b88792c: 1
#   geoloc_8b48f0cdd7d616e3ea52aa9e8caf77114f665ef4: 1
#   geoloc_f9c8abdc40408f837e66fcc2f5ad24706230811f: 1
#   geoloc_e0d7ef6a9804047a6672d5cf078fc9f62e08e19a: 1
#   geoloc_90303910509b3727d8266519d2a4ddb797857cf2: 1
#   geoloc_087ae8a2df64d2d83fb6cc71852301f622a89f87: 1
#   geoloc_68e11798f11dd517d386c0701798cf0c51005318: 1
#   geoloc_ffd265995da7d50926b82194b8c1c0d240d18ca8: 1
#   geoloc_255457bdf7839e29a81a1a0240d0362d9d59f07b: 1
# ...
#   geoloc_bd67a6fe301f88dc9da392bfbb7ae1ae999ea26e: 1
#   geoloc_3a97485d93b78e98f71cba89e4b812237d7945ec: 1
#   geoloc_ce618938d762fb388132982f0f8b696b5d15a786: 1
#   geoloc_dcda8f6012249b487066d98d6ec419f60eb0b4e3: 1
#   geoloc_07d0fba123fefa73e23454efaaa976378092a0b6: 1
#   geoloc_02c12253f5b9fff40734c79e76b9a8f3c1ceea9c: 1
#   geoloc_b4044c85e4e6f4c25fd998b8cf637dde46b7afbc: 1
#   geoloc_fd4424ec0338ccf678255eea376056b97348e211: 1
#   geoloc_53a087e3ed71372b2871fbb263776aeaa9fafa93: 1
#   geoloc_93ace62dd2e6ca9347871497b8e411e97035aad1: 1
#   geoloc_72cb141353888bed375d4fa0527c6c7cdca2b824: 1
#   geoloc_e0aef59ef59d46a1d293a37938af06277141a925: 1
#   geoloc_dabc26034c4e7367ba4536b6d4d4e8dd81b7dcbe: 1
#   geoloc_518313ed6f1f79091ca9dd5324295b3de9598195: 1
#   geoloc_7a46115a6dec2fbad7b9464e74995427cc85e75d: 1
#   geoloc_842e6be295aea3b0257c2d0b930b43c50d055dbc: 1
#   geoloc_d21dafb40f258ee21676983c75eae7d8739d5db4: 1
#   geoloc_66eae475182e1738f998e7e013a255676e03f42d: 1
#   geoloc_47e1ea2d467fdbd6df358a055be1e1738c36666c: 1
#   geoloc_7d7373bdf9bdb5c6c8ee867bd660de3403cf561e: 1
#   geoloc_d3ec0195b2f31b8d6e15c69d71c8d151e762c91e: 1
#   geoloc_ce1270af3175766be54e63d061439c9a47aa4364: 1
#   geoloc_79c1cb2842084b74f348f0768edad034937420ca: 1
#   geoloc_06a4c11f935d28689d8d7ccda78d139fc503c1d5: 1
#   geoloc_770bce25a9d8aa4a83fb38c11bd3b2871e211206: 1
#   geoloc_c40b5e11b0c3cc264494e11c5b87d677ea134dc6: 1
#   geoloc_744ce95b395b226a18b7d30b46d3c9e725f0892a: 1
#   geoloc_eaf85051a4395406159b8ca5e3a6b1dd2d072d2d: 1
#   geoloc_5b9f7a98689f43675b4feea4a00d7c7d9924d1d1: 1
#   geoloc_88d9520cc0ac931fe225eba52ea248f85ba5ce96: 1
#   geoloc_b8c66a5c71fd8079f4a7a825a82e83e0e6a85e2f: 1
#   geoloc_2155063192f362c1a18bb2091d8c237d737b8b6a: 1
#   geoloc_1ca7cf4496302285ed202ea980527dfe3f0be699: 1
#   geoloc_0e2cc205513a71a35b8c4b9631944eba18165080: 1
#   geoloc_f3a8be7a2c1a9955c1f8860677fa366e959269f6: 1
#   geoloc_626f39573262893b5df1fc7a19e9c41694e36fca: 1
#   geoloc_e2a86761df9332b3324cf9b01a0ea476c5c7ecf9: 1
#   geoloc_3523d4ff5a6e723303f024f96c739e071741a772: 1
#   geoloc_080ef4317d5dbc978081516f2a8d6d4f4db7367f: 1
#   geoloc_301d70045261055cf6187ee2f1494d24390a47e3: 1
#   geoloc_05c7ea37d2d17aebe63aa9ea312b0aa4268f9f45: 1
#   geoloc_8ee6f4dc9860c7300fe16ff37535ef08b0ec8a35: 1
#   geoloc_492dbc722835701c99f467f883a8190c5d022306: 1
#   geoloc_02fdaa8e31511eda497656f0fcf5829d73eb1ad8: 1
#   geoloc_b5c2e75fec92d8db1c5aa217c5972a0cf56842a1: 1
#   geoloc_67db230eb7914fe0faca04d75c6b3427280faf19: 1
#   geoloc_ef7c74f5ebe32a644b373a8ca0d7cf1bfdffae84: 1
#   geoloc_4bdf02506332780a840c6a5201b2d069b939fb43: 1
#   geoloc_f6f0afe102fdc0c5a8ff6c0df5337dfe87ab6aee: 1
#   geoloc_b5e97508a073e674c2ea884d20e1c2f44537da39: 1
#   geoloc_f4f484b1c08dfbe10d950063829d7452bfd23fdb: 1
#   geoloc_b9ba5ba323b4395b8b9e6a9a2225efbb8be968ea: 1
#   geoloc_252d2e54cd7baa77caa91fc69a0e1286da024f37: 1
#   geoloc_1df6b2ac9c721921d6ec6b9077a76be693b6b7b9: 1
#   geoloc_3d691877ec258ad6609b19895c190f1ad712d83f: 1
#   geoloc_7bb71cdc124d16db65e8a2f27612c4dd6ce6c84f: 1
#   geoloc_e1afb909ff8fd92c64bb9e41ed5ee05a89afd601: 1
#   geoloc_1ba4b6916b2eb6c4d7e5dadf1cc850652875a460: 1
#   geoloc_fe69619452779239782dbbaef071cdf649794f37: 1
#   geoloc_4b3e65edbfcaf5e05400e1c32efa8f6ebeee9a78: 1
#   geoloc_3a167b1bae953892d60d992aa5430f71871c1e23: 1
#   geoloc_c4ee00278683ad9241b94d69ed0aebb996953d93: 1
#   geoloc_0b013eb3abda61c60c1287c214dd9cec40535ec2: 1
#   geoloc_c1e00ba3e5107de265ae25a47e11fec027ae5f87: 1
#   geoloc_714d2b9a8faae3e919b1cdda80896b8213bbed8f: 1
#   geoloc_b5c2cea88dd5141e7e7f7964ef313a2a44058262: 1
#   geoloc_c90e788625d702d23940c9f747ac0cdf4bd6b35a: 1
#   geoloc_abc115c660bbe07740136b05d6ba869160062519: 1
#   geoloc_1b850856ed062922307444abe2b257b1d7a25004: 1
#   geoloc_58fe05280b3202c63b3ad4bf8e791ab6707a24ac: 1
#   geoloc_83e2943742feed04addeb32c1b549c5ff11ba1c0: 1
#   geoloc_9dd24b73ff3c79c025997691584af58e4be3207e: 1
#   geoloc_d92c499f9cb5e35c34df13d676b74f5d85acb6f2: 1
#   geoloc_71e7948e6d2cf0a25345052d32dc353f8677249d: 1
#   geoloc_00c03a5622ac32826ac958b18cfd23bf4a458b8c: 1
#   geoloc_64d4e145e5a3549611bfabf2a0b1cf77dc944e8b: 1
#   geoloc_0a62f558c88460fcd0c966d984324b76094c7510: 1
#   geoloc_f8858d59af084e45cbbf4362077202013a0217ca: 1
#   geoloc_c17de4dc72b5ca69fdcf660c476a540d3c7f6584: 1
#   geoloc_7aa5fa89019e9e3884ba15a49e05fdbce8435574: 1
#   geoloc_5bd93ea5019b5683198e01063f1bc017a01c9263: 1
#   geoloc_64c94b483fc20380200ffdb5b752b58cc62864dd: 1
#   geoloc_454cac572c914047c78c94e86dc933d02c9acb37: 1
#   geoloc_8fb44ae8f26b1c59b94345a08051b0ac0e21a2fd: 1
#   geoloc_e01a8609efd82137867d6fde36460367558c6b22: 1
#   geoloc_11b95894bf2e8177d6f446e783642704ac00b9df: 1
#   geoloc_7ee93830de27c40ed1da6efa40bf7a0da959c814: 1
#   geoloc_417b921900f0a259a40fa48e7dad5ef1e81d41ec: 1
#   geoloc_13261ceafc0df70a5cfb7acc072c16107e9bd4d9: 1
#   geoloc_babdd12b7963e83ebbe771ea9575d7b05712c17a: 1
#   geoloc_d6aebeaa2da17834b66df4ef7acb5d4cc83038e9: 1
#   geoloc_4437a58a747565e55b88c7a1182f13dcc3ea1e08: 1
#   geoloc_151c868d94d7076e2c596a1ead76c6d0e803b819: 1
#   geoloc_0a5df1ae80657bf2f000f53348f95daf8eda9827: 1
#   geoloc_5122dc67f98fdb3f3c472143e72b91d835c4354c: 1
#   geoloc_b50ee580034e5d3f7e685612fc11f1425d173e61: 1
#   geoloc_931676fe3c867abd035dcbc30a5a48565f3c55f0: 1
#   geoloc_009a1809c8c0afb5724b632f3b39d31ca24c9b08: 1
#   geoloc_7c57391c3e3302f569854a46cf0689ff8cf1e176: 1
#   geoloc_3b76cca57a0c056697cca59b37023f0e3731563a: 1
#   geoloc_f55914ba7b5a44c5aa5fb799c026d5523d5f7df7: 1
#   geoloc_d4276e1c8ad2d9db1abfbc0f78f0497abb239c00: 1
#   geoloc_697e5ef3544cc5b2801e2d86b301294b9e6f44f4: 1
#   geoloc_229bb1c8a9d21e372ef3444b6fff131dcff45420: 1
#   geoloc_f380c2a9ff64b2202709d1b5f1d7980816ca5c6e: 1
#   geoloc_3a1ebe32795d154c75c42ab256716dd6de475f9e: 1
#   geoloc_061633db73c8fe000a8a722da7d587fbb4a38799: 1
#   geoloc_9efa82906bbcafa6129a7f1f59f00bd406b14f6b: 1
#   geoloc_8d3c81b87a6068afbf257e817ea9e172d375a7c1: 1
#   geoloc_8f6b22d3aca8e4bb1437baf4a9eb6b48f2b2fc42: 1
#   geoloc_7f9c734ca5af2912a71648a6d2b2020be73ca512: 1
#   geoloc_847811dede3f796c7bad43c447b1bb640362b1a0: 1
#   geoloc_c0b5b8b63ddbc951f02b5471d21f407418447d4a: 1
#   geoloc_8ac5695996f57b6049791835c49b4dd504b65008: 1
#   geoloc_2c9987d97718a75c44f3b2a3157b2d3bf97bfb3c: 1
#   geoloc_916e6d9034ce1eb2f6b8d3c699c2336e39e6b74b: 1
#   geoloc_88e4d53f7494eabc649726e06345b7b657a5dbaf: 1
#   geoloc_dc37c42afa8304bba71f117f4ffdf3fe82022c7a: 1
#   geoloc_693d597c625326dcdb8475b964589c1f7b4bfdbc: 1
#   geoloc_c90bb0a1e2e10858934eddb5e998aaff803c5efb: 1
#   geoloc_7cfce1d9bf662ca03f582746cedf45a41e28dcb3: 1
#   geoloc_b5eaea2f7410570b4f7efc07795391863671bc40: 1
#   geoloc_c096d0d44ac85ce1e0e1e69416b29898828fb376: 1
#   geoloc_1ea2f0025a2970bd639fd84584fefa338d1e83c3: 1
#   geoloc_34abb554cf63b22bd8c1e6f327d0d997ff339eb2: 1
#   geoloc_4c6d52df688eb0a91ddf05d1510d21530c01825c: 1
#   geoloc_bbb8c2ae41114b0e98a3baee514deae096436b46: 1
#   geoloc_6eb5981da0d1f9973515a08340fb952c043ccd3c: 1
#   geoloc_467e47ed261719c06ddd2f376716133f48c4d311: 1
#   geoloc_3a0b49acf80baa6af7ac8e2531b1cd23682f75f1: 1
#   geoloc_7203d3e1f328eaa58a24b34016f8fe7cd97fc5b2: 1
#   geoloc_bed2508c94821af1808e82e0d1b8c5679e702522: 1
#   geoloc_220878eed3069309e5e68e7597abba01baece2c1: 1
#   geoloc_303027780ecfb6057af876b0651169c67de6b380: 1
#   geoloc_996ff920b3daccbee591f13c93c807b0bc6d4653: 1
#   geoloc_28e4500472fc6f9ef82f874f57fbe07262615798: 1
#   geoloc_cce9aebb4eaecd02ac1794d600e4ed318fcef9c2: 1
#   geoloc_c8d26e9036a7e93a87e8dab95aa0153529c9ac82: 1
#   geoloc_03f456d810e4ea5a75a1c773517e3057b07b2928: 1
#   geoloc_f45d746f5ac74e9bb3542b01d6d11d041c01169e: 1
#   geoloc_83a89d5971ddba0cc0dce8cbc3b1326244a0a6cb: 1
#   geoloc_e4d06d4ea524a4787878d057d7cb76aba4caa568: 1
#   geoloc_bb97b150eb4f1d02b9a4cb5b4f483c209f754283: 1
#   geoloc_dceed2e2f5d597edbb450746f96cd41fd78cdbbb: 1
#   geoloc_86ccf53a19057d75c3574f34e041d8706e5ce9e9: 1
#   geoloc_d95ff1ab99a93e913c4d042392973b9aa996c4a7: 1
#   geoloc_de5fddb0d8cd515d90dfb5d65b44dae9cf336166: 1
#   geoloc_eb29f60ddb4012c14cee83f0cf1fe8c100b2fae9: 1
#   geoloc_79b99856462eeb9fab4163b607a36da77f5b748c: 1
#   geoloc_7300ce005f6477d6a13817ccf572c9b8ed7e5978: 1
#   geoloc_9fa8a5cefb227246d7708e469bf6cde8f8e6f92d: 1
#   geoloc_e59f148c6b3e013bd3973cbd11df253ac16c8de8: 1
#   geoloc_cd1dfaaca77d490318976572bb44dbdc7c409f80: 1
#   geoloc_41f759e151afb648ea522e8a629ca0f072bbd895: 1
#   geoloc_752cdb45e48cf61ff54110043c43f9d1bdf22071: 1
#   geoloc_61f966b275f6135840e043c38150732b31a35985: 1
#   geoloc_ad0cec03db24e6ee8b5afaa50f52f6521ff84736: 1
#   geoloc_ac5fbc8e858af10d8b6dd7525561eccca93b0bbe: 1
#   geoloc_df751f4e6b77861b3b37a33f924e22fa0fd62902: 1
#   geoloc_1bcdc3b57fbfb17d770187308c64f6c5e535ddba: 1
#   geoloc_065733522c2b9f945f411c6e8f61aea695cd1bf4: 1
#   geoloc_60b8e254804d5c2882e09b8e4e9791b429be61b4: 1
#   geoloc_4cce99067e0653ae68fd9cdf35b6bc40e2aa4009: 1
#   geoloc_924b59aaa6ac226f7d94942f005a376459b7e293: 1
#   geoloc_73daec0a32524a4d393dbd6a532553a7f1763f92: 1
#   geoloc_e8f4138772992487e6d05dc6a6c5d333addc8e29: 1
#   geoloc_debc4a243402f2333c3a0523928e26d9b7379942: 1
#   geoloc_c94e9bc7a14134acc63bf40329abd4f24d501b6a: 1
#   geoloc_96c51895fdbd766e28f480e763d0ca0ba4997901: 1
#   geoloc_afc13924ae741c49f8543a8f90f5505f72fb5c27: 1
#   geoloc_0bd016c8abbcd5a56431cc9c9029aef1d6144e53: 1
#   geoloc_4d8315581fd2bd8ee9fb0d296a78c7cca9543d9e: 1
#   geoloc_3804be742f13ef2e031ebfc171dc129fdc59785c: 1
#   geoloc_bd0c8868122b08bda68a62b7143cb71b282d4358: 1
#   geoloc_d638ac4413644bd3223d99ca34389715a3fd5746: 1
#   geoloc_3634d877c8b248be7bc45a3ebbb7ddc980731bba: 1
#   geoloc_5fffa1dfc620922429a49b51eae7eb81d56843cb: 1
#   geoloc_255a54ca8428e8114e3b21cdd49fb60c6941dea2: 1
#   geoloc_ccff467cb1255aa6b39b0cf1cb441182e2326e32: 1
#   geoloc_1d2a8aa57a03e73469d12dcf99be7e45d6b982b0: 1
#   geoloc_aea35a43ea043ee3012a978dd19697f0eadba2c3: 1
#   geoloc_0e4b25a7c76c35a68321088a281f36b75077cf54: 1
#   geoloc_80853b88a51dd3da5a438b04c455d638aaa48154: 1
#   geoloc_f3c7b86a144e7f29ac0eaf1c2f87f2c294ae6bbc: 1
#   geoloc_0b01d58d29a6178ef6585b1f100588cf8c27242c: 1
#   geoloc_fad27ed434d101d146f76f0779e904f234636775: 1
#   geoloc_6426854bcded83a70b6728ed3719654f5c8009f0: 1
#   geoloc_35beb45850a18170245f25e76b97700aafd58e3d: 1
#   geoloc_59b1412caf8bd8dd07471b7a2c2a41d32a7f835c: 1
#   geoloc_5c6b2e37669515cb86c0a4b947e393eb9ccd4eff: 1
#   geoloc_0a901542fa136983936018e989e5c96d58ca996a: 1
#   geoloc_efaeaf712823ce3d82ac7be5a77e2422abe7224a: 1
#   geoloc_76b5bd3450d10d36c3fac5ad02aa426e2523c6c7: 1
#   geoloc_c62e1dcf0f229b6c8a9b69027dee9986b138f4af: 1
#   geoloc_736f7a45b26f720d88af1843e5bd127149083026: 1
#   geoloc_da0627a1f8d4e2a2acc39534bb81aac841113ca8: 1
#   geoloc_312294a9d6a7e8d0381c66aa243890efd43b8ec6: 1
#   geoloc_cbb2a76c3f733ce0e067a9a0e0c782aea8ae4129: 1
#   geoloc_01cd3d128b6ad4bfd1ca61c157a0bd753297d1a2: 1
#   geoloc_53256d94cac25709ee8c696938a3b8d140a14a24: 1
#   geoloc_930d30a531cb01ad0c2af452880dc246ed6ce588: 1
#   geoloc_5a5de178acb1c7093f00313c16d13578a185304a: 1
#   geoloc_289b9c023d93ad4f4d559c48254c11ac0b0af486: 1
#   geoloc_b1fd9e3999d7339da930f7fa6b153cc2e23aa9f5: 1
#   geoloc_4ffa1297bf603d86c412aa792cecb9deb550e079: 1
#   geoloc_9f0c7979104c520ba7c754036806f9bac5ef2639: 1
#   geoloc_a620d15d5f0c5ea8d7d6686d22094f8063fde1cf: 1
#   geoloc_97866475805f53179801f6f7ce9f5e27efa2c750: 1
#   geoloc_f2e7ffded48aa0506b5b26f5b20699bb32c18973: 1
#   geoloc_42e08d64e4180b32406d9defc59f12f9846996f9: 1
#   geoloc_d2ec60cf44dc5ca11518abb87c606909db006776: 1
#   geoloc_8da3b04202502d60ac996555cfc5a93b0a05ae76: 1
#   geoloc_d4a41f0d0ec66a498c19b7baf07941e39ad2da6b: 1
#   geoloc_d5661bf582ee5f743c4fe9626aad43f97a0113f3: 1
#   geoloc_849afa81a8b6991e9c7f4ba62fe0a840ed8c6a5f: 1
#   geoloc_8878b18d4ae273f6f90fb320508d6fd29c88a2d5: 1
#   geoloc_bb13ec8c3872b5767d3b3b4660a02fedd9088929: 1
#   geoloc_e3fb2d5fc2520d3c6251a23afc834bd113bd8fc1: 1
#   geoloc_02d88e63b39c6aa34436b353db62ee0649d2b1d8: 1
#   geoloc_864c97212450833ab546e4f0035623acb6188f68: 1
#   geoloc_720ed76af8644c431ef1f60bce477f0b98c54b30: 1
#   geoloc_ca3d7f80005038db10cdb3e284917bfdd09ec209: 1
#   geoloc_c22e58ae35052b586950d1cd422cdfb289db2ec9: 1
#   geoloc_9f686fe4a7bbcbf682dfb569c3e8cc417b17f8a6: 1
#   geoloc_c600f5938ff7f78f0e358f9abe369bde18d54472: 1
#   geoloc_5e0be069e34e3a6a31af8a436672aea00538df1a: 1
#   geoloc_89e3c5631ff9adab0cffb98bf5c38ff0fbfe40c1: 1
#   geoloc_f505364f31d0bdb0b22b3f55688468ed6074edc9: 1
#   geoloc_02af55323b34c1c1d1fbc14a8edaf43f7e32a154: 1
#   geoloc_a3b730a35797724fa87f175d3ab3a2f2a07cb2ab: 1
#   geoloc_84da209d45e4b92ee559df626a327aad1dba7e6c: 1
#   geoloc_7b3b12d1c9065cc25ff4886615d9b73ecaeeb6af: 1
#   geoloc_f21dac87b153b3652cb0edadbadde3f4d7c0b521: 1
#   geoloc_6cb34759937a1b2c04cc1b2500ee34564e0924c5: 1
#   geoloc_3113fc93f06a929cfc24d0bfbaef03a69b5e98da: 1
#   geoloc_4387010a96a2f744eeef6ed362e8687f82d8d3f4: 1
#   geoloc_a2caf426662079415389437e50fb9e722a6e9748: 1
#   geoloc_74b9b5ff451be6c3aa4c66885075fc7a53d4f306: 1
#   geoloc_f83a59f98b17047dbaa33caea3f9a9a06ee88cb8: 1
#   geoloc_9463597080940f1229858782591242c7e75715df: 1
#   geoloc_326d09b1c45958dc204a1bb6ef027ef65e891360: 1
#   geoloc_3f23382cc945abe88a96e6c83534ffb42afa6488: 1
#   geoloc_7083b73614a6c8f080ee6f4206a5cc85c6a4310b: 1
#   geoloc_2583b177a0a2e25d53631cc20671e2556fad5637: 1
#   geoloc_660c38ecc7c1ec9993239afe62aa35704dc73ee6: 1
#   geoloc_79c8958263af4b216650f83f42e4733efefefa4e: 1
#   geoloc_fd1103529eaec54f84b091ff3378f1f92667008d: 1
#   geoloc_5bfd0a2364b587104a5be4dce04ba399eed2b6ca: 1
#   geoloc_0abc402fa16c1284a32315ad91a1e15031180c11: 1
#   geoloc_376d871a4f5ee6f2b4a78eb4a32874c95bee67b6: 1
#   geoloc_df3a4e7ecf92cd20c91d43e7496b0e6a1f360645: 1
#   geoloc_a91b4ba234d2c60373744c52dea1f1dc6bb2fb61: 1
#   geoloc_08d3aebd9775150c6cfec6d04542b91d6771238c: 1
#   geoloc_5e4972058f9f53af1cc2fff47c1650768e30a5be: 1
#   geoloc_3ff59ac4f33a62bd46045058d2005d70cde10b7e: 1
#   geoloc_57631e9b7c7cff6fc7118e7121d66b82daed80aa: 1
#   geoloc_1e57670945f912ab06427b9984d171b953447fa9: 1
#   geoloc_3373cb422bda2836e77d317bae16cb4aec586f62: 1
#   geoloc_1d38a6a9d0c912a64c022d39b57a309b7d492cdc: 1
#   geoloc_f97799eec8ed4fd87ff50a5e52feaa2e3e4ac0fe: 1
#   geoloc_29a9afcdfabdf51f45993406d874f0ab03823778: 1
#   geoloc_ec040fc643ab47367b2446b95abde886027f6a60: 1
#   geoloc_eedf2bbad635fec29df885f16993a2bad3f5fd78: 1
#   geoloc_9fb6b8ba6fb78b68256475a4bce5a093e481ac69: 1
#   geoloc_8099501972da60986f68c7b25a3d2ca0ab442729: 1
#   geoloc_61756b714e69c06c980a404bbb46267c460cbc66: 1
#   geoloc_e2aeb133c4dd04806ff919981cfbc24c0034e677: 1
#   geoloc_2f62272789ec7e5d22e78bb4f316646652d9397d: 1
#   geoloc_f8c8eab8fdccfb40c51b778a38d05dd81e48ae1e: 1
#   geoloc_ecdc0b8fa86ddc6ea6366a6751413a34f42231a8: 1
#   geoloc_0c4b3435e20faf79d27240d6c4194674a602f009: 1
#   geoloc_2f68e90b69d05ef5daa4db0b2102c26cb8aab522: 1
#   geoloc_cc512e969e037ad778dc3f94453abdb39c94c0c0: 1
#   geoloc_4f5463f9930395d4da8544dccc579c4a6214acfb: 1
#   geoloc_f6050445cedc9aebd9bc4bc0230a052477ce00cf: 1
#   geoloc_9cb82d86b453aae1a6dd3f646b7ad4aac906ab6f: 1
#   geoloc_b62a52b70960484fa5337042e98fb237375414e8: 1
#   geoloc_593be8b8d45e3e0e15b40164a54b65cd6bb6a934: 1
#   geoloc_b5dfd3a7d0f9d2d594fd07d35690cd5ab095f8cd: 1
#   geoloc_7a2c86003d474557ab38f876d81c526fadb651cc: 1
#   geoloc_5a18707b8960cba096305111755e952605cdf30f: 1
#   geoloc_e903edbb03d21ef3386c22f827f2ab001d75b846: 1
#   geoloc_720bd7e2956cb90f647e944ae3c9cc935c145bc0: 1
#   geoloc_b5fe5e5d842817c51a3487177416a0625ba1663d: 1
#   geoloc_85606bf74caf0a20dea55908fc1f9ff599b80ffc: 1
#   geoloc_3af16a8fe557735b4b23a1ede84dc0783a4544ea: 1
#   geoloc_817463650eda9728be2d8f55fae4f03d8886d79f: 1
#   geoloc_6cc287e57958b5d365608eddc5b8cad439f3769c: 1
#   geoloc_44d515c2dc2bd48b72f9a5a948051838db53edbe: 1
#   geoloc_4b4d9cd796d17d8e271f298d4efeaec5bafcf139: 1
#   geoloc_515342539693a553c49b503865076bda473f7029: 1
#   geoloc_b3aa21bf1c8e22bc21d5d4a7a3d75a1f2969389f: 1
#   geoloc_789dc7c7d3a058b627acf5e634cff4903c89b5f3: 1
#   geoloc_efc3883091d4abfc05117633cc62db009448b6d0: 1
#   geoloc_f309e72c21573e7689099f2662ad5b26f64f28e4: 1
#   geoloc_6df6b31fd2699ebf0a6c5bb0b60fa54dba78fbfe: 1
#   geoloc_c02c33b478dac3cfe98fa7fb23cf5d869002750b: 1
#   geoloc_c75e7259c8db366c012ea287e2a2f68214bdf2f9: 1
#   geoloc_f10868bfff1606f30c3dcd05b4fa8b703d45122c: 1
#
# ⚠️ Note: This is only 10K out of 11,637,144 records
#    Full dataset would take ~6.2s with PQG
#    SQL took 13.68ms for all records

# %% [markdown]
# **Comparison:**
# - **SQL**: Instant, uses columnar storage optimizations
# - **PQG**: Must iterate through records, 100-1000x slower
# - **Winner**: 🏆 SQL for bulk aggregations (no contest)
#
# **Key insight:** Never use PQG for GROUP BY operations on large datasets.

# %% [markdown]
# ## Decision Matrix: When to Use PQG vs SQL
#
# | Use Case | PQG | SQL | Rationale |
# |----------|-----|-----|----------|
# | Single node lookup | ✅ | ⚠️ | PQG handles row_id conversion, cleaner API |
# | Multi-hop traversal (1-3 hops) | ✅ | ⚠️ | PQG more readable, acceptable performance |
# | Reverse graph traversal | ⚠️ | ✅ | SQL more efficient for "what points to X" |
# | Bulk aggregations (10K+ rows) | ❌ | ✅ | SQL dramatically faster |
# | Visualization queries | ❌ | ✅ | Need specific projections, performance-critical |
# | Data quality analysis | ❌ | ✅ | Requires full table scans |
# | Learning/prototyping | ✅ | ⚠️ | PQG clearer for understanding graph structure |
# | Production web queries | ❌ | ✅ | SQL already optimized and tested |
#
# **Legend:**
# - ✅ Recommended
# - ⚠️ Works but not optimal
# - ❌ Not recommended
#
# ## Key Takeaways
#
# 1. **PQG excels at:**
#    - Interactive exploration and learning
#    - Single node operations with relationship expansion
#    - Development and prototyping
#    - Making complex graph patterns more readable
#
# 2. **SQL excels at:**
#    - Bulk operations and aggregations
#    - Reverse traversals ("what points to X")
#    - Production performance-critical queries
#    - Full table scans and statistics
#
# 3. **Best practice: Hybrid approach**
#    - Use PQG for exploratory analysis
#    - Identify performance bottlenecks
#    - Optimize critical sections with SQL
#    - Document both approaches for learning value
#
# 4. **Performance rule of thumb:**
#    - <100 nodes: PQG is fine
#    - 100-1000 nodes: PQG acceptable, profile first
#    - 1000+ nodes: Strongly prefer SQL
#    - Aggregations: Always use SQL

# %% [markdown]
# ## Next Steps
#
# To explore further:
#
# 1. **Try modifying the traversal functions** - Add more hops, different predicates
# 2. **Explore other entity types** - Try with SamplingSite, IdentifiedConcept, etc.
# 3. **Compare with existing notebook** - See `oc_parquet_analysis_enhanced.ipynb` for production SQL patterns
# 4. **Contribute back to PQG** - If you find API gaps or performance improvements
#
# ## Resources
#
# - **PQG Repository:** https://github.com/isamplesorg/pqg
# - **PQG Documentation:** https://github.com/isamplesorg/pqg/tree/main/docs
# - **Integration Plan:** `/Users/raymondyee/C/src/iSamples/isamples-python/PQG_INTEGRATION_PLAN.md`
# - **Production Examples:** `oc_parquet_analysis_enhanced.ipynb`
